# %% [markdown]
# <a href="https://colab.research.google.com/github/sreenithya2118/mini-project/blob/main/MiniProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install simpy
# Out:
# Collecting simpy
#   Downloading simpy-4.1.1-py3-none-any.whl (27 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.1.1

# %%
class Host:
    def __init__(self, id, cpu_capacity, memory_capacity):
        self.id = id
        self.cpu_capacity = cpu_capacity
        self.memory_capacity = memory_capacity
        self.available_cpu = cpu_capacity
        self.available_memory = memory_capacity
        self.vms = []

    def allocate_resources(self, vm):
        if self.available_cpu >= vm.cpu and self.available_memory >= vm.memory:
            self.available_cpu -= vm.cpu
            self.available_memory -= vm.memory
            self.vms.append(vm)
            return True
        return False

    def release_resources(self, vm):
        self.available_cpu += vm.cpu
        self.available_memory += vm.memory
        self.vms.remove(vm)

# %%
class VM:
    def __init__(self, id, cpu, memory):
        self.id = id
        self.cpu = cpu
        self.memory = memory
        self.host = None

# %%
import random

def generate_vm_workload(env, arrival_rate, vm_list):
    while True:
        yield env.timeout(random.expovariate(arrival_rate))
        vm_id = len(vm_list) + 1
        cpu_demand = random.randint(1, 10)
        memory_demand = random.randint(1, 10)
        vm = VM(vm_id, cpu_demand, memory_demand)
        vm_list.append(vm)
        env.process(handle_vm_lifetime(env, vm))

# %%
simulation_duration = 1000  # Total time units for the simulation
arrival_rate = 0.1  # Average arrival rate of VMs per time unit
min_cpu = 1
max_cpu = 10
min_memory = 1
max_memory = 10
#Q-learning parameters
alpha = 0.1  # Learning rate
gamma = 0.9  # Discount factor
epsilon = 0.1  # Exploration rate

# %%
class QLearningAgent:
    def __init__(self, alpha, gamma, epsilon):
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.q_table = {}

    def get_state(self, host, vm):
        return (host.id, vm.id)

    def choose_action(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(['migrate', 'stay'])
        else:
            return max(self.q_table.get(state, {'migrate': 0, 'stay': 0}), key=self.q_table.get(state, {'migrate': 0, 'stay': 0}).get)

    def update_q_value(self, state, action, reward, next_state):
        old_value = self.q_table.get(state, {}).get(action, 0)
        future_reward = max(self.q_table.get(next_state, {}).values(), default=0)
        new_value = old_value + self.alpha * (reward + self.gamma * future_reward - old_value)
        if state not in self.q_table:
            self.q_table[state] = {}
        self.q_table[state][action] = new_value

# %%
def calculate_reward(host):
    utilization = (host.cpu_capacity - host.available_cpu) / host.cpu_capacity
    return utilization  # Simple reward based on CPU utilization

# %%
def handle_vm_lifetime(env, vm):
    global hosts, agent
    # Find a host to allocate the VM
    for host in hosts:
        if host.allocate_resources(vm):
            vm.host = host
            break

    # VM is active for some time
    lifetime = random.randint(50, 150)
    yield env.timeout(lifetime)

    # Decide whether to migrate or not using Q-learning
    state = agent.get_state(vm.host, vm)
    action = agent.choose_action(state)

    if action == 'migrate':
        for host in hosts:
            if host != vm.host and host.allocate_resources(vm):
                vm.host.release_resources(vm)
                vm.host = host
                break

    reward = calculate_reward(vm.host)
    next_state = agent.get_state(vm.host, vm)
    agent.update_q_value(state, action, reward, next_state)

    # VM leaves the system
    vm.host.release_resources(vm)

# %%
import simpy

env = simpy.Environment()
hosts = [Host(i, 100, 100) for i in range(10)]
vms = []
agent = QLearningAgent(alpha, gamma, epsilon)

env.process(generate_vm_workload(env, arrival_rate, vms))
env.run(until=simulation_duration)

# %%
for host in hosts:
    print(f'Host {host.id} final utilization: {(host.cpu_capacity - host.available_cpu) / host.cpu_capacity:.2f}')
# Out:
# Host 0 final utilization: 0.81
# Host 1 final utilization: 0.00
# Host 2 final utilization: 0.00
# Host 3 final utilization: 0.00
# Host 4 final utilization: 0.00
# Host 5 final utilization: 0.00
# Host 6 final utilization: 0.00
# Host 7 final utilization: 0.00
# Host 8 final utilization: 0.00
# Host 9 final utilization: 0.00

# %%
import simpy
import random

class Host:
    def __init__(self, id, cpu_capacity, memory_capacity):
        self.id = id
        self.cpu_capacity = cpu_capacity
        self.memory_capacity = memory_capacity
        self.available_cpu = cpu_capacity
        self.available_memory = memory_capacity
        self.vms = []

    def allocate_resources(self, vm):
        if self.available_cpu >= vm.cpu and self.available_memory >= vm.memory:
            self.available_cpu -= vm.cpu
            self.available_memory -= vm.memory
            self.vms.append(vm)
            return True
        return False

    def release_resources(self, vm):
        self.available_cpu += vm.cpu
        self.available_memory += vm.memory
        self.vms.remove(vm)

class VM:
    def __init__(self, id, cpu, memory, start_time, end_time):
        self.id = id
        self.cpu = cpu
        self.memory = memory
        self.start_time = start_time
        self.end_time = end_time
        self.host = None

class QLearningAgent:
    def __init__(self, alpha, gamma, epsilon):
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.q_table = {}

    def get_state(self, host, vm):
        return (host.id, vm.id)

    def choose_action(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(['migrate', 'stay'])
        else:
            return max(self.q_table.get(state, {'migrate': 0, 'stay': 0}), key=self.q_table.get(state, {'migrate': 0, 'stay': 0}).get)

    def update_q_value(self, state, action, reward, next_state):
        old_value = self.q_table.get(state, {}).get(action, 0)
        future_reward = max(self.q_table.get(next_state, {}).values(), default=0)
        new_value = old_value + self.alpha * (reward + self.gamma * future_reward - old_value)
        if state not in self.q_table:
            self.q_table[state] = {}
        self.q_table[state][action] = new_value

def calculate_reward(host):
    utilization = (host.cpu_capacity - host.available_cpu) / host.cpu_capacity
    return utilization  # Simple reward based on CPU utilization

def handle_vm_lifetime(env, vm, hosts, agent):
    for host in hosts:
        if host.allocate_resources(vm):
            vm.host = host
            break

    if vm.host is None:
        return  # No host could allocate the VM

    lifetime = vm.end_time - vm.start_time
    yield env.timeout(lifetime)

    state = agent.get_state(vm.host, vm)
    action = agent.choose_action(state)

    if action == 'migrate':
        for host in hosts:
            if host != vm.host and host.allocate_resources(vm):
                vm.host.release_resources(vm)
                vm.host = host
                break

    reward = calculate_reward(vm.host)
    next_state = agent.get_state(vm.host, vm)
    agent.update_q_value(state, action, reward, next_state)

    vm.host.release_resources(vm)

def generate_random_vm_workload(env, hosts, agent):
    while True:
        start_time = env.now
        end_time = start_time + random.randint(100, 1000)
        cpu_demand = random.uniform(10, 80)  # Increased range of CPU demand
        memory_demand = random.uniform(10, 80)  # Increased range of memory demand

        vm_id = start_time
        vm = VM(vm_id, cpu_demand, memory_demand, start_time, end_time)
        env.process(handle_vm_lifetime(env, vm, hosts, agent))
        yield env.timeout(random.randint(10, 100))

def print_host_utilization(hosts):
    for host in hosts:
        utilization = (host.cpu_capacity - host.available_cpu) / host.cpu_capacity
        print(f'Host {host.id} utilization: {utilization:.2f}')

# Simulation parameters
simulation_duration = 3600
alpha = 0.1
gamma = 0.9
epsilon = 0.1

env = simpy.Environment()
hosts = [Host(i, random.randint(80, 120), random.randint(80, 120)) for i in range(10)]  # Variance in host capacities
agent = QLearningAgent(alpha, gamma, epsilon)

env.process(generate_random_vm_workload(env, hosts, agent))
env.run(until=simulation_duration)

print_host_utilization(hosts)
# Out:
# Host 0 utilization: 0.54
# Host 1 utilization: 0.46
# Host 2 utilization: 0.51
# Host 3 utilization: 0.60
# Host 4 utilization: 0.76
# Host 5 utilization: 0.00
# Host 6 utilization: 0.12
# Host 7 utilization: 0.47
# Host 8 utilization: 0.68
# Host 9 utilization: 0.00

# %%
import random
import simpy

class Host:
    def __init__(self, id, cpu_capacity, memory_capacity):
        self.id = id
        self.cpu_capacity = cpu_capacity
        self.memory_capacity = memory_capacity
        self.available_cpu = cpu_capacity
        self.available_memory = memory_capacity
        self.vms = []

    def allocate_resources(self, vm):
        if self.available_cpu >= vm.cpu and self.available_memory >= vm.memory:
            self.available_cpu -= vm.cpu
            self.available_memory -= vm.memory
            self.vms.append(vm)
            print(f"VM {vm.id} allocated to Host {self.id}")
            return True
        return False

    def release_resources(self, vm):
        self.available_cpu += vm.cpu
        self.available_memory += vm.memory
        self.vms.remove(vm)
        print(f"VM {vm.id} released from Host {self.id}")

class VM:
    def __init__(self, id, cpu, memory, start_time, end_time):
        self.id = id
        self.cpu = cpu
        self.memory = memory
        self.start_time = start_time
        self.end_time = end_time
        self.host = None

class QLearningAgent:
    def __init__(self, alpha, gamma, epsilon):
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.q_table = {}

    def get_state(self, host, vm):
        return (host.id, vm.id)

    def choose_action(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(['migrate', 'stay'])
        else:
            return max(self.q_table.get(state, {'migrate': 0, 'stay': 0}), key=self.q_table.get(state, {'migrate': 0, 'stay': 0}).get)

    def update_q_value(self, state, action, reward, next_state):
        old_value = self.q_table.get(state, {}).get(action, 0)
        future_reward = max(self.q_table.get(next_state, {}).values(), default=0)
        new_value = old_value + self.alpha * (reward + self.gamma * future_reward - old_value)
        if state not in self.q_table:
            self.q_table[state] = {}
        self.q_table[state][action] = new_value

def calculate_reward(host):
    utilization = (host.cpu_capacity - host.available_cpu) / host.cpu_capacity
    return utilization

def handle_vm_lifetime(env, vm, hosts, agent):
    for host in hosts:
        if host.allocate_resources(vm):
            vm.host = host
            break

    if vm.host is None:
        print(f"VM {vm.id} could not be allocated to any host")
        return

    print_host_utilization(hosts, "before migration")

    lifetime = vm.end_time - vm.start_time
    yield env.timeout(lifetime)

    state = agent.get_state(vm.host, vm)
    action = agent.choose_action(state)

    if action == 'migrate':
        for host in hosts:
            if host != vm.host and host.allocate_resources(vm):
                vm.host.release_resources(vm)
                vm.host = host
                break

    reward = calculate_reward(vm.host)
    next_state = agent.get_state(vm.host, vm)
    agent.update_q_value(state, action, reward, next_state)

    vm.host.release_resources(vm)

    print_host_utilization(hosts, "after migration")

def generate_vm_workload(env, hosts, agent):
    while True:
        start_time = env.now
        end_time = start_time + random.randint(5, 15)
        cpu_demand = random.uniform(10, 50)
        memory_demand = random.uniform(10, 50)

        vm_id = start_time
        vm = VM(vm_id, cpu_demand, memory_demand, start_time, end_time)
        env.process(handle_vm_lifetime(env, vm, hosts, agent))
        yield env.timeout(random.randint(1, 10))  # Wait for a random interval before creating the next VM

def print_host_utilization(hosts, migration_phase):
    print(f"Host utilization {migration_phase}:")
    for host in hosts:
        utilization = (host.cpu_capacity - host.available_cpu) / host.cpu_capacity
        print(f'Host {host.id} utilization: {utilization:.2f}')

# Simulation parameters
simulation_duration = 1000  # Short duration for quick test
alpha = 0.1
gamma = 0.9
epsilon = 0.1

# Initialize environment and components
env = simpy.Environment()
hosts = [Host(i, 100, 100) for i in range(5)]  # Reduced number of hosts for simplicity
agent = QLearningAgent(alpha, gamma, epsilon)

print("Starting simulation...")
env.process(generate_vm_workload(env, hosts, agent))
env.run(until=simulation_duration)
print("Simulation finished.")

print_host_utilization(hosts, "final")
# Out:
# Starting simulation...
# VM 0 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.45
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 4 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.57
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 0 allocated to Host 1
# VM 0 released from Host 0
# VM 0 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.12
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 11 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.35
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 16 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.55
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 4 allocated to Host 1
# VM 4 released from Host 0
# VM 4 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.43
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 11 allocated to Host 1
# VM 11 released from Host 0
# VM 11 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.20
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 24 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.57
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 16 allocated to Host 1
# VM 16 released from Host 0
# VM 16 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.37
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 28 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.52
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 24 allocated to Host 1
# VM 24 released from Host 0
# VM 24 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.15
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 36 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.40
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 38 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.82
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 28 allocated to Host 1
# VM 28 released from Host 0
# VM 28 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.67
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 38 allocated to Host 1
# VM 38 released from Host 0
# VM 38 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.25
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 48 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.44
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 36 allocated to Host 1
# VM 36 released from Host 0
# VM 36 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.19
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 53 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.57
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 60 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.57
# Host 1 utilization: 0.32
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 53 allocated to Host 1
# VM 53 released from Host 0
# VM 53 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.19
# Host 1 utilization: 0.32
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 48 allocated to Host 1
# VM 48 released from Host 0
# VM 48 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.32
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 68 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.32
# Host 1 utilization: 0.32
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 60 allocated to Host 0
# VM 60 released from Host 1
# VM 60 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.32
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 78 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.42
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 68 allocated to Host 1
# VM 68 released from Host 0
# VM 68 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.10
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 86 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.24
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 78 allocated to Host 1
# VM 78 released from Host 0
# VM 78 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.14
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 86 allocated to Host 1
# VM 86 released from Host 0
# VM 86 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 94 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.14
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 94 allocated to Host 1
# VM 94 released from Host 0
# VM 94 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 102 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.12
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 106 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.58
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 102 allocated to Host 1
# VM 102 released from Host 0
# VM 102 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.46
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 106 allocated to Host 1
# VM 106 released from Host 0
# VM 106 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 115 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.38
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 125 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.52
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 128 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.52
# Host 1 utilization: 0.46
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 115 allocated to Host 1
# VM 115 released from Host 0
# VM 115 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.14
# Host 1 utilization: 0.46
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 131 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.29
# Host 1 utilization: 0.46
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 125 allocated to Host 1
# VM 125 released from Host 0
# VM 125 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.14
# Host 1 utilization: 0.46
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 128 allocated to Host 0
# VM 128 released from Host 1
# VM 128 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.14
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 139 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.24
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 131 allocated to Host 1
# VM 131 released from Host 0
# VM 131 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.10
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 145 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.52
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 147 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.75
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 139 allocated to Host 1
# VM 139 released from Host 0
# VM 139 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.65
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 145 allocated to Host 1
# VM 145 released from Host 0
# VM 145 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.24
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 152 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.58
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 157 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.97
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 147 allocated to Host 1
# VM 147 released from Host 0
# VM 147 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.73
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 157 allocated to Host 1
# VM 157 released from Host 0
# VM 157 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.34
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 152 allocated to Host 1
# VM 152 released from Host 0
# VM 152 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 167 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.26
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 172 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.55
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 172 allocated to Host 1
# VM 172 released from Host 0
# VM 172 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.26
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 167 allocated to Host 1
# VM 167 released from Host 0
# VM 167 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 182 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.39
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 185 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.67
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 186 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.83
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 182 allocated to Host 1
# VM 182 released from Host 0
# VM 182 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.44
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 185 allocated to Host 1
# VM 185 released from Host 0
# VM 185 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.16
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 194 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.49
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 198 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.85
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 186 allocated to Host 1
# VM 186 released from Host 0
# VM 186 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.70
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 194 allocated to Host 1
# VM 194 released from Host 0
# VM 194 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.37
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 202 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.85
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 204 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.85
# Host 1 utilization: 0.37
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 202 allocated to Host 1
# VM 202 released from Host 0
# VM 202 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.37
# Host 1 utilization: 0.37
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 198 allocated to Host 1
# VM 198 released from Host 0
# VM 198 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.37
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 213 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.28
# Host 1 utilization: 0.37
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 204 allocated to Host 0
# VM 204 released from Host 1
# VM 204 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.28
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 213 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 220 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.41
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 223 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.87
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 223 allocated to Host 1
# VM 223 released from Host 0
# VM 223 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.41
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 220 allocated to Host 1
# VM 220 released from Host 0
# VM 220 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 233 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.27
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 235 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.38
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 245 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.38
# Host 1 utilization: 0.19
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 233 allocated to Host 1
# VM 233 released from Host 0
# VM 233 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.11
# Host 1 utilization: 0.19
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 235 allocated to Host 1
# VM 235 released from Host 0
# VM 235 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.19
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 254 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.47
# Host 1 utilization: 0.19
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 245 allocated to Host 0
# VM 245 released from Host 1
# VM 245 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.47
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 258 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.71
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 259 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.71
# Host 1 utilization: 0.45
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 254 allocated to Host 1
# VM 254 released from Host 0
# VM 254 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.25
# Host 1 utilization: 0.45
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 258 allocated to Host 1
# VM 258 released from Host 0
# VM 258 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.45
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 269 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.39
# Host 1 utilization: 0.45
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 259 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.39
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 275 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.75
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 279 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.93
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 269 allocated to Host 1
# VM 269 released from Host 0
# VM 269 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.53
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 279 allocated to Host 1
# VM 279 released from Host 0
# VM 279 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.36
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 287 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.76
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 275 allocated to Host 1
# VM 275 released from Host 0
# VM 275 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.40
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 293 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.78
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 287 allocated to Host 1
# VM 287 released from Host 0
# VM 287 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.37
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 293 allocated to Host 1
# VM 293 released from Host 0
# VM 293 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 299 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.41
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 299 allocated to Host 1
# VM 299 released from Host 0
# VM 299 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 307 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.43
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 307 allocated to Host 1
# VM 307 released from Host 0
# VM 307 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 316 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.28
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 321 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.58
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 316 allocated to Host 1
# VM 316 released from Host 0
# VM 316 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.30
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 324 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.50
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 325 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.50
# Host 1 utilization: 0.42
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 321 allocated to Host 1
# VM 321 released from Host 0
# VM 321 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.20
# Host 1 utilization: 0.42
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 324 allocated to Host 1
# VM 324 released from Host 0
# VM 324 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.42
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 332 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.19
# Host 1 utilization: 0.42
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 334 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.61
# Host 1 utilization: 0.42
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 325 allocated to Host 2
# VM 325 released from Host 1
# VM 325 released from Host 2
# Host utilization after migration:
# Host 0 utilization: 0.61
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 338 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.61
# Host 1 utilization: 0.44
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 332 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.42
# Host 1 utilization: 0.44
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 334 allocated to Host 1
# VM 334 released from Host 0
# VM 334 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.44
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 347 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.12
# Host 1 utilization: 0.44
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 338 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.12
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 349 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.27
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 347 allocated to Host 1
# VM 347 released from Host 0
# VM 347 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.15
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 349 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 358 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.12
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 365 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.32
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 371 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.62
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 358 allocated to Host 1
# VM 358 released from Host 0
# VM 358 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.50
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 365 allocated to Host 1
# VM 365 released from Host 0
# VM 365 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.30
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 381 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.44
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 385 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.63
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 371 allocated to Host 1
# VM 371 released from Host 0
# VM 371 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.33
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 381 allocated to Host 1
# VM 381 released from Host 0
# VM 381 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.19
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 395 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.58
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 385 allocated to Host 1
# VM 385 released from Host 0
# VM 385 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.39
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 405 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.68
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 395 allocated to Host 1
# VM 395 released from Host 0
# VM 395 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.29
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 407 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.52
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 405 allocated to Host 1
# VM 405 released from Host 0
# VM 405 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.22
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 416 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.53
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 419 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.53
# Host 1 utilization: 0.32
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 407 allocated to Host 1
# VM 407 released from Host 0
# VM 407 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.30
# Host 1 utilization: 0.32
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 423 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.54
# Host 1 utilization: 0.32
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 416 allocated to Host 1
# VM 416 released from Host 0
# VM 416 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.24
# Host 1 utilization: 0.32
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 419 allocated to Host 0
# VM 419 released from Host 1
# VM 419 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.24
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 431 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.46
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 423 allocated to Host 1
# VM 423 released from Host 0
# VM 423 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.22
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 433 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.70
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 435 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.70
# Host 1 utilization: 0.34
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 431 allocated to Host 1
# VM 431 released from Host 0
# VM 431 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.47
# Host 1 utilization: 0.34
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 433 allocated to Host 1
# VM 433 released from Host 0
# VM 433 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.34
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 445 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.43
# Host 1 utilization: 0.34
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 435 allocated to Host 0
# VM 435 released from Host 1
# VM 435 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.43
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 449 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.85
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 454 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.85
# Host 1 utilization: 0.22
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 445 allocated to Host 1
# VM 445 released from Host 0
# VM 445 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.42
# Host 1 utilization: 0.22
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 449 allocated to Host 1
# VM 449 released from Host 0
# VM 449 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.22
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 462 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.27
# Host 1 utilization: 0.22
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 454 allocated to Host 0
# VM 454 released from Host 1
# VM 454 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.27
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 467 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.71
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 462 allocated to Host 1
# VM 462 released from Host 0
# VM 462 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.44
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 473 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.76
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 478 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.76
# Host 1 utilization: 0.20
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 473 allocated to Host 1
# VM 473 released from Host 0
# VM 473 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.44
# Host 1 utilization: 0.20
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 467 allocated to Host 1
# VM 467 released from Host 0
# VM 467 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.20
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 481 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.29
# Host 1 utilization: 0.20
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 483 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.49
# Host 1 utilization: 0.20
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 487 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.59
# Host 1 utilization: 0.20
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 481 allocated to Host 1
# VM 481 released from Host 0
# VM 481 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.30
# Host 1 utilization: 0.20
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 488 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.30
# Host 1 utilization: 0.32
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 478 allocated to Host 0
# VM 478 released from Host 1
# VM 478 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.30
# Host 1 utilization: 0.12
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 496 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.72
# Host 1 utilization: 0.12
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 483 allocated to Host 1
# VM 483 released from Host 0
# VM 483 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.52
# Host 1 utilization: 0.12
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 487 allocated to Host 1
# VM 487 released from Host 0
# VM 487 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.42
# Host 1 utilization: 0.12
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 488 allocated to Host 0
# VM 488 released from Host 1
# VM 488 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.42
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 500 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.75
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 501 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.75
# Host 1 utilization: 0.18
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 504 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.75
# Host 1 utilization: 0.57
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 496 allocated to Host 2
# VM 496 released from Host 0
# VM 496 released from Host 2
# Host utilization after migration:
# Host 0 utilization: 0.34
# Host 1 utilization: 0.57
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 500 allocated to Host 1
# VM 500 released from Host 0
# VM 500 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.57
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 510 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.30
# Host 1 utilization: 0.57
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 504 allocated to Host 0
# VM 504 released from Host 1
# VM 504 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.30
# Host 1 utilization: 0.18
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 501 allocated to Host 0
# VM 501 released from Host 1
# VM 501 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.30
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 518 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.70
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 510 allocated to Host 1
# VM 510 released from Host 0
# VM 510 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.40
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 518 allocated to Host 1
# VM 518 released from Host 0
# VM 518 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 524 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.13
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 529 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.32
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 533 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.32
# Host 1 utilization: 0.19
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 535 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.32
# Host 1 utilization: 0.59
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 524 allocated to Host 2
# VM 524 released from Host 0
# VM 524 released from Host 2
# Host utilization after migration:
# Host 0 utilization: 0.18
# Host 1 utilization: 0.59
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 539 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.62
# Host 1 utilization: 0.59
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 529 allocated to Host 2
# VM 529 released from Host 0
# VM 529 released from Host 2
# Host utilization after migration:
# Host 0 utilization: 0.43
# Host 1 utilization: 0.59
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 542 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.82
# Host 1 utilization: 0.59
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 533 allocated to Host 2
# VM 533 released from Host 1
# VM 533 released from Host 2
# Host utilization after migration:
# Host 0 utilization: 0.82
# Host 1 utilization: 0.41
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 535 allocated to Host 2
# VM 535 released from Host 1
# VM 535 released from Host 2
# Host utilization after migration:
# Host 0 utilization: 0.82
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 551 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.94
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 539 allocated to Host 1
# VM 539 released from Host 0
# VM 539 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.51
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 542 allocated to Host 1
# VM 542 released from Host 0
# VM 542 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.12
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 556 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.44
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 551 allocated to Host 1
# VM 551 released from Host 0
# VM 551 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.32
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 561 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.61
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 556 allocated to Host 1
# VM 556 released from Host 0
# VM 556 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.29
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 570 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.66
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 572 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.66
# Host 1 utilization: 0.32
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 561 allocated to Host 1
# VM 561 released from Host 0
# VM 561 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.37
# Host 1 utilization: 0.32
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 575 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.67
# Host 1 utilization: 0.32
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 570 allocated to Host 1
# VM 570 released from Host 0
# VM 570 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.29
# Host 1 utilization: 0.32
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 572 allocated to Host 0
# VM 572 released from Host 1
# VM 572 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.29
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 575 allocated to Host 1
# VM 575 released from Host 0
# VM 575 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 585 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.45
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 591 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.57
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 585 allocated to Host 1
# VM 585 released from Host 0
# VM 585 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.13
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 591 allocated to Host 1
# VM 591 released from Host 0
# VM 591 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 601 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.10
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 601 allocated to Host 1
# VM 601 released from Host 0
# VM 601 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 610 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.46
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 611 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.88
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 610 allocated to Host 1
# VM 610 released from Host 0
# VM 610 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.42
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 611 allocated to Host 1
# VM 611 released from Host 0
# VM 611 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 621 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.32
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 625 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.70
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 627 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.70
# Host 1 utilization: 0.48
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 621 allocated to Host 1
# VM 621 released from Host 0
# VM 621 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.38
# Host 1 utilization: 0.48
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 625 allocated to Host 1
# VM 625 released from Host 0
# VM 625 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.48
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 630 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.19
# Host 1 utilization: 0.48
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 632 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.55
# Host 1 utilization: 0.48
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 627 allocated to Host 2
# VM 627 released from Host 1
# VM 627 released from Host 2
# Host utilization after migration:
# Host 0 utilization: 0.55
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 630 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.36
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 632 allocated to Host 1
# VM 632 released from Host 0
# VM 632 released from Host 1
# Host utilization after migration:
# ...
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 790 allocated to Host 1
# VM 790 released from Host 0
# VM 790 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.37
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 801 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.29
# Host 1 utilization: 0.37
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 804 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.41
# Host 1 utilization: 0.37
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 794 allocated to Host 0
# VM 794 released from Host 1
# VM 794 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.41
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 801 allocated to Host 1
# VM 801 released from Host 0
# VM 801 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.12
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 804 allocated to Host 1
# VM 804 released from Host 0
# VM 804 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 814 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.47
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 820 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.97
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 814 allocated to Host 1
# VM 814 released from Host 0
# VM 814 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.49
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 823 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.97
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 823 allocated to Host 1
# VM 823 released from Host 0
# VM 823 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.49
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 820 allocated to Host 1
# VM 820 released from Host 0
# VM 820 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 830 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.34
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 832 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.67
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 839 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.89
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 841 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.89
# Host 1 utilization: 0.24
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 832 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.57
# Host 1 utilization: 0.24
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 830 allocated to Host 1
# VM 830 released from Host 0
# VM 830 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.23
# Host 1 utilization: 0.24
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 839 allocated to Host 1
# VM 839 released from Host 0
# VM 839 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.24
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 846 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.38
# Host 1 utilization: 0.24
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 841 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.38
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 846 allocated to Host 1
# VM 846 released from Host 0
# VM 846 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 855 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.23
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 862 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.44
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 855 allocated to Host 1
# VM 855 released from Host 0
# VM 855 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.21
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 862 allocated to Host 1
# VM 862 released from Host 0
# VM 862 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 872 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.11
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 876 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.28
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 879 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.56
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 872 allocated to Host 1
# VM 872 released from Host 0
# VM 872 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.45
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 876 allocated to Host 1
# VM 876 released from Host 0
# VM 876 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.29
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 889 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.55
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 879 allocated to Host 1
# VM 879 released from Host 0
# VM 879 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.26
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 889 allocated to Host 1
# VM 889 released from Host 0
# VM 889 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 897 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.25
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 905 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.56
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 907 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.56
# Host 1 utilization: 0.49
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 897 allocated to Host 1
# VM 897 released from Host 0
# VM 897 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.31
# Host 1 utilization: 0.49
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 905 allocated to Host 1
# VM 905 released from Host 0
# VM 905 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.49
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 916 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.40
# Host 1 utilization: 0.49
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 907 allocated to Host 0
# VM 907 released from Host 1
# VM 907 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.40
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 921 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.68
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 923 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.68
# Host 1 utilization: 0.40
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 916 allocated to Host 1
# VM 916 released from Host 0
# VM 916 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.28
# Host 1 utilization: 0.40
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 921 allocated to Host 1
# VM 921 released from Host 0
# VM 921 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.40
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 923 allocated to Host 0
# VM 923 released from Host 1
# VM 923 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 932 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.18
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 933 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.50
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 932 allocated to Host 1
# VM 932 released from Host 0
# VM 932 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.32
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 943 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.54
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 933 allocated to Host 1
# VM 933 released from Host 0
# VM 933 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.21
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 948 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.62
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 950 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.62
# Host 1 utilization: 0.34
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 948 allocated to Host 1
# VM 948 released from Host 0
# VM 948 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.21
# Host 1 utilization: 0.34
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 943 allocated to Host 1
# VM 943 released from Host 0
# VM 943 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.34
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 950 allocated to Host 0
# VM 950 released from Host 1
# VM 950 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 960 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.14
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 960 allocated to Host 1
# VM 960 released from Host 0
# VM 960 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 966 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.41
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 971 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.52
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 974 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.74
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 975 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.74
# Host 1 utilization: 0.42
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 966 allocated to Host 1
# VM 966 released from Host 0
# VM 966 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.34
# Host 1 utilization: 0.42
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 971 allocated to Host 1
# VM 971 released from Host 0
# VM 971 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.22
# Host 1 utilization: 0.42
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 975 allocated to Host 0
# VM 975 released from Host 1
# VM 975 released from Host 0
# Host utilization after migration:
# Host 0 utilization: 0.22
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 984 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.44
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 974 allocated to Host 1
# VM 974 released from Host 0
# VM 974 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.22
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 987 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.51
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 989 allocated to Host 1
# Host utilization before migration:
# Host 0 utilization: 0.51
# Host 1 utilization: 0.41
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 991 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.75
# Host 1 utilization: 0.41
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 984 allocated to Host 1
# VM 984 released from Host 0
# VM 984 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.54
# Host 1 utilization: 0.41
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 991 allocated to Host 1
# VM 991 released from Host 0
# VM 991 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.29
# Host 1 utilization: 0.41
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 987 allocated to Host 1
# VM 987 released from Host 0
# VM 987 released from Host 1
# Host utilization after migration:
# Host 0 utilization: 0.00
# Host 1 utilization: 0.41
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# VM 999 allocated to Host 0
# Host utilization before migration:
# Host 0 utilization: 0.18
# Host 1 utilization: 0.41
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# Simulation finished.
# Host utilization final:
# Host 0 utilization: 0.18
# Host 1 utilization: 0.41
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00

# %%
import random
import simpy

class Host:
    def __init__(self, id, cpu_capacity, memory_capacity):
        self.id = id
        self.cpu_capacity = cpu_capacity
        self.memory_capacity = memory_capacity
        self.available_cpu = cpu_capacity
        self.available_memory = memory_capacity
        self.vms = []

    def allocate_resources(self, vm):
        if self.available_cpu >= vm.cpu and self.available_memory >= vm.memory:
            self.available_cpu -= vm.cpu
            self.available_memory -= vm.memory
            self.vms.append(vm)
            print(f"VM {vm.id} allocated to Host {self.id}")
            return True
        return False

    def release_resources(self, vm):
        self.available_cpu += vm.cpu
        self.available_memory += vm.memory
        self.vms.remove(vm)
        print(f"VM {vm.id} released from Host {self.id}")

class VM:
    def __init__(self, id, cpu, memory, start_time, end_time):
        self.id = id
        self.cpu = cpu
        self.memory = memory
        self.start_time = start_time
        self.end_time = end_time
        self.host = None

class QLearningAgent:
    def __init__(self, alpha, gamma, epsilon):
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.q_table = {}

    def get_state(self, host, vm):
        return (host.id, vm.id)

    def choose_action(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(['migrate', 'stay'])
        else:
            return max(self.q_table.get(state, {'migrate': 0, 'stay': 0}), key=self.q_table.get(state, {'migrate': 0, 'stay': 0}).get)

    def update_q_value(self, state, action, reward, next_state):
        old_value = self.q_table.get(state, {}).get(action, 0)
        future_reward = max(self.q_table.get(next_state, {}).values(), default=0)
        new_value = old_value + self.alpha * (reward + self.gamma * future_reward - old_value)
        if state not in self.q_table:
            self.q_table[state] = {}
        self.q_table[state][action] = new_value

def calculate_reward(host):
    utilization = (host.cpu_capacity - host.available_cpu) / host.cpu_capacity
    return utilization

def handle_vm_lifetime(env, vm, hosts, agent, migration_count, correct_migrations, total_actions):
    for host in hosts:
        if host.allocate_resources(vm):
            vm.host = host
            break

    if vm.host is None:
        print(f"VM {vm.id} could not be allocated to any host")
        return

    lifetime = vm.end_time - vm.start_time
    yield env.timeout(lifetime)

    state = agent.get_state(vm.host, vm)
    action = agent.choose_action(state)
    total_actions[0] += 1

    initial_reward = calculate_reward(vm.host)

    if action == 'migrate':
        for host in hosts:
            if host != vm.host and host.allocate_resources(vm):
                vm.host.release_resources(vm)
                vm.host = host
                migration_count[0] += 1
                break

    reward = calculate_reward(vm.host)
    next_state = agent.get_state(vm.host, vm)
    agent.update_q_value(state, action, reward, next_state)

    if reward > initial_reward:
        correct_migrations[0] += 1

    vm.host.release_resources(vm)

def generate_vm_workload(env, hosts, agent, migration_count, correct_migrations, total_actions):
    while True:
        start_time = env.now
        end_time = start_time + random.randint(5, 15)
        cpu_demand = random.uniform(10, 50)
        memory_demand = random.uniform(10, 50)

        vm_id = start_time
        vm = VM(vm_id, cpu_demand, memory_demand, start_time, end_time)
        env.process(handle_vm_lifetime(env, vm, hosts, agent, migration_count, correct_migrations, total_actions))
        yield env.timeout(random.randint(1, 10))  # Wait for a random interval before creating the next VM

def calculate_efficiency(hosts, total_time, migration_count, correct_migrations, total_actions):
    total_utilization = sum((host.cpu_capacity - host.available_cpu) / host.cpu_capacity for host in hosts) / len(hosts)
    print(f"Average Host Utilization: {total_utilization:.2f}")
    print(f"Number of Migrations: {migration_count[0]}")
    efficiency = total_utilization - (migration_count[0] / total_time)  # Simplified efficiency calculation
    accuracy = correct_migrations[0] / total_actions[0] if total_actions[0] > 0 else 0
    print(f"Efficiency: {efficiency:.2f}")
    print(f"Accuracy: {accuracy:.2f}")

def print_host_utilization(hosts):
    for host in hosts:
        utilization = (host.cpu_capacity - host.available_cpu) / host.cpu_capacity
        print(f'Host {host.id} utilization: {utilization:.2f}')

# Simulation parameters
simulation_duration = 1000  # Short duration for quick test
alpha = 0.1
gamma = 0.9
epsilon = 0.1

# Initialize environment and components
env = simpy.Environment()
hosts = [Host(i, 100, 100) for i in range(5)]  # Reduced number of hosts for simplicity
agent = QLearningAgent(alpha, gamma, epsilon)
migration_count = [0]  # Using a list to pass the migration count by reference
correct_migrations = [0]  # Track correct migrations
total_actions = [0]  # Track total actions

print("Starting simulation...")
env.process(generate_vm_workload(env, hosts, agent, migration_count, correct_migrations, total_actions))
env.run(until=simulation_duration)
print("Simulation finished.")

print_host_utilization(hosts)
calculate_efficiency(hosts, simulation_duration, migration_count, correct_migrations, total_actions)
# Out:
# Starting simulation...
# VM 0 allocated to Host 0
# VM 6 allocated to Host 0
# VM 0 allocated to Host 1
# VM 0 released from Host 0
# VM 0 released from Host 1
# VM 11 allocated to Host 0
# VM 16 allocated to Host 0
# VM 11 allocated to Host 1
# VM 11 released from Host 0
# VM 11 released from Host 1
# VM 18 allocated to Host 1
# VM 6 allocated to Host 1
# VM 6 released from Host 0
# VM 6 released from Host 1
# VM 19 allocated to Host 0
# VM 20 allocated to Host 1
# VM 24 allocated to Host 1
# VM 19 allocated to Host 2
# VM 19 released from Host 0
# VM 19 released from Host 2
# VM 16 allocated to Host 2
# VM 16 released from Host 0
# VM 16 released from Host 2
# VM 18 allocated to Host 0
# VM 18 released from Host 1
# VM 18 released from Host 0
# VM 20 allocated to Host 0
# VM 20 released from Host 1
# VM 20 released from Host 0
# VM 33 allocated to Host 0
# VM 24 allocated to Host 0
# VM 24 released from Host 1
# VM 24 released from Host 0
# VM 41 allocated to Host 0
# VM 33 allocated to Host 1
# VM 33 released from Host 0
# VM 33 released from Host 1
# VM 44 allocated to Host 0
# VM 41 allocated to Host 1
# VM 41 released from Host 0
# VM 41 released from Host 1
# VM 52 allocated to Host 0
# VM 44 allocated to Host 1
# VM 44 released from Host 0
# VM 44 released from Host 1
# VM 59 allocated to Host 0
# VM 52 allocated to Host 1
# VM 52 released from Host 0
# VM 52 released from Host 1
# VM 60 allocated to Host 0
# VM 59 allocated to Host 1
# VM 59 released from Host 0
# VM 59 released from Host 1
# VM 64 allocated to Host 0
# VM 70 allocated to Host 0
# VM 60 allocated to Host 1
# VM 60 released from Host 0
# VM 60 released from Host 1
# VM 75 allocated to Host 0
# VM 70 allocated to Host 1
# VM 70 released from Host 0
# VM 70 released from Host 1
# VM 64 allocated to Host 1
# VM 64 released from Host 0
# VM 64 released from Host 1
# VM 79 allocated to Host 0
# VM 79 allocated to Host 1
# VM 79 released from Host 0
# VM 79 released from Host 1
# VM 89 allocated to Host 0
# VM 75 allocated to Host 1
# VM 75 released from Host 0
# VM 75 released from Host 1
# VM 92 allocated to Host 0
# VM 89 allocated to Host 1
# VM 89 released from Host 0
# VM 89 released from Host 1
# VM 99 allocated to Host 0
# VM 92 allocated to Host 1
# VM 92 released from Host 0
# VM 92 released from Host 1
# VM 99 allocated to Host 1
# VM 99 released from Host 0
# VM 99 released from Host 1
# VM 107 allocated to Host 0
# VM 111 allocated to Host 0
# VM 107 released from Host 0
# VM 120 allocated to Host 0
# VM 124 allocated to Host 0
# VM 111 allocated to Host 1
# VM 111 released from Host 0
# VM 111 released from Host 1
# VM 120 allocated to Host 1
# VM 120 released from Host 0
# VM 120 released from Host 1
# VM 127 allocated to Host 0
# VM 131 allocated to Host 1
# VM 127 allocated to Host 1
# VM 127 released from Host 0
# VM 127 released from Host 1
# VM 124 allocated to Host 1
# VM 124 released from Host 0
# VM 124 released from Host 1
# VM 137 allocated to Host 0
# VM 141 allocated to Host 0
# VM 137 allocated to Host 1
# VM 137 released from Host 0
# VM 137 released from Host 1
# VM 144 allocated to Host 0
# VM 145 allocated to Host 1
# VM 131 allocated to Host 2
# VM 131 released from Host 1
# VM 131 released from Host 2
# VM 141 allocated to Host 1
# VM 141 released from Host 0
# VM 141 released from Host 1
# VM 147 allocated to Host 0
# VM 144 allocated to Host 1
# VM 144 released from Host 0
# VM 144 released from Host 1
# VM 145 allocated to Host 0
# VM 145 released from Host 1
# VM 145 released from Host 0
# VM 147 allocated to Host 1
# VM 147 released from Host 0
# VM 147 released from Host 1
# VM 157 allocated to Host 0
# VM 161 allocated to Host 0
# VM 157 allocated to Host 1
# VM 157 released from Host 0
# VM 157 released from Host 1
# VM 168 allocated to Host 0
# VM 161 allocated to Host 1
# VM 161 released from Host 0
# VM 161 released from Host 1
# VM 174 allocated to Host 0
# VM 168 allocated to Host 1
# VM 168 released from Host 0
# VM 168 released from Host 1
# VM 181 allocated to Host 0
# VM 174 allocated to Host 1
# VM 174 released from Host 0
# VM 174 released from Host 1
# VM 189 allocated to Host 0
# VM 181 allocated to Host 1
# VM 181 released from Host 0
# VM 181 released from Host 1
# VM 195 allocated to Host 0
# VM 189 allocated to Host 1
# VM 189 released from Host 0
# VM 189 released from Host 1
# VM 195 allocated to Host 1
# VM 195 released from Host 0
# VM 195 released from Host 1
# VM 203 allocated to Host 0
# VM 208 allocated to Host 0
# VM 203 allocated to Host 1
# VM 203 released from Host 0
# VM 203 released from Host 1
# VM 214 allocated to Host 0
# VM 218 allocated to Host 0
# VM 208 allocated to Host 1
# VM 208 released from Host 0
# VM 208 released from Host 1
# VM 218 allocated to Host 1
# VM 218 released from Host 0
# VM 218 released from Host 1
# VM 228 allocated to Host 0
# VM 214 allocated to Host 1
# VM 214 released from Host 0
# VM 214 released from Host 1
# VM 238 allocated to Host 0
# VM 239 allocated to Host 1
# VM 241 allocated to Host 0
# VM 228 allocated to Host 1
# VM 228 released from Host 0
# VM 228 released from Host 1
# VM 246 allocated to Host 1
# VM 239 allocated to Host 2
# VM 239 released from Host 1
# VM 239 released from Host 2
# VM 238 allocated to Host 1
# VM 238 released from Host 0
# VM 238 released from Host 1
# VM 241 allocated to Host 1
# VM 241 released from Host 0
# VM 241 released from Host 1
# VM 253 allocated to Host 0
# VM 260 allocated to Host 0
# VM 246 allocated to Host 0
# VM 246 released from Host 1
# VM 246 released from Host 0
# VM 261 allocated to Host 0
# VM 253 allocated to Host 1
# VM 253 released from Host 0
# VM 253 released from Host 1
# VM 266 allocated to Host 0
# VM 261 allocated to Host 1
# VM 261 released from Host 0
# VM 261 released from Host 1
# VM 267 allocated to Host 1
# VM 260 allocated to Host 1
# VM 260 released from Host 0
# VM 260 released from Host 1
# VM 270 allocated to Host 0
# VM 266 allocated to Host 1
# VM 266 released from Host 0
# VM 266 released from Host 1
# VM 274 allocated to Host 0
# VM 267 allocated to Host 0
# VM 267 released from Host 1
# VM 267 released from Host 0
# VM 270 allocated to Host 1
# VM 270 released from Host 0
# VM 270 released from Host 1
# VM 279 allocated to Host 0
# VM 274 allocated to Host 1
# VM 274 released from Host 0
# VM 274 released from Host 1
# VM 287 allocated to Host 0
# VM 279 allocated to Host 1
# VM 279 released from Host 0
# VM 279 released from Host 1
# VM 293 allocated to Host 0
# VM 287 allocated to Host 1
# VM 287 released from Host 0
# VM 287 released from Host 1
# VM 303 allocated to Host 0
# VM 304 allocated to Host 1
# VM 293 allocated to Host 1
# VM 293 released from Host 0
# VM 293 released from Host 1
# VM 307 allocated to Host 0
# VM 309 allocated to Host 1
# VM 304 allocated to Host 0
# VM 304 released from Host 1
# VM 304 released from Host 0
# VM 303 allocated to Host 1
# VM 303 released from Host 0
# VM 303 released from Host 1
# VM 307 allocated to Host 1
# VM 307 released from Host 0
# VM 307 released from Host 1
# VM 314 allocated to Host 0
# VM 309 allocated to Host 0
# VM 309 released from Host 1
# VM 309 released from Host 0
# VM 324 allocated to Host 0
# VM 314 allocated to Host 1
# VM 314 released from Host 0
# VM 314 released from Host 1
# VM 333 allocated to Host 0
# VM 324 allocated to Host 1
# VM 324 released from Host 0
# VM 324 released from Host 1
# VM 340 allocated to Host 0
# VM 341 allocated to Host 1
# VM 343 allocated to Host 1
# VM 333 allocated to Host 2
# VM 333 released from Host 0
# VM 333 released from Host 2
# VM 340 allocated to Host 2
# VM 340 released from Host 0
# VM 340 released from Host 2
# VM 341 allocated to Host 0
# VM 341 released from Host 1
# VM 341 released from Host 0
# VM 343 allocated to Host 0
# VM 343 released from Host 1
# VM 343 released from Host 0
# VM 351 allocated to Host 0
# VM 353 allocated to Host 0
# VM 354 allocated to Host 1
# VM 359 allocated to Host 1
# VM 354 allocated to Host 2
# VM 354 released from Host 1
# VM 354 released from Host 2
# VM 353 allocated to Host 1
# VM 353 released from Host 0
# VM 353 released from Host 1
# VM 351 allocated to Host 1
# VM 351 released from Host 0
# VM 351 released from Host 1
# VM 364 allocated to Host 0
# VM 359 allocated to Host 0
# VM 359 released from Host 1
# VM 359 released from Host 0
# VM 371 allocated to Host 0
# VM 364 allocated to Host 1
# VM 364 released from Host 0
# VM 364 released from Host 1
# VM 371 allocated to Host 1
# VM 371 released from Host 0
# VM 371 released from Host 1
# VM 381 allocated to Host 0
# VM 388 allocated to Host 0
# VM 392 allocated to Host 1
# VM 388 allocated to Host 1
# VM 388 released from Host 0
# VM 388 released from Host 1
# VM 381 allocated to Host 1
# VM 381 released from Host 0
# VM 381 released from Host 1
# VM 395 allocated to Host 0
# VM 392 allocated to Host 0
# VM 392 released from Host 1
# VM 392 released from Host 0
# VM 405 allocated to Host 0
# VM 406 allocated to Host 0
# VM 395 allocated to Host 1
# VM 395 released from Host 0
# VM 395 released from Host 1
# VM 413 allocated to Host 1
# VM 405 allocated to Host 1
# VM 405 released from Host 0
# VM 405 released from Host 1
# VM 406 allocated to Host 1
# VM 406 released from Host 0
# VM 406 released from Host 1
# VM 418 allocated to Host 0
# VM 413 allocated to Host 0
# VM 413 released from Host 1
# VM 413 released from Host 0
# VM 420 allocated to Host 0
# VM 430 allocated to Host 1
# VM 420 allocated to Host 1
# VM 420 released from Host 0
# VM 420 released from Host 1
# VM 431 allocated to Host 0
# VM 418 allocated to Host 1
# VM 418 released from Host 0
# VM 418 released from Host 1
# VM 441 allocated to Host 0
# VM 431 allocated to Host 1
# VM 431 released from Host 0
# VM 431 released from Host 1
# VM 430 allocated to Host 0
# VM 430 released from Host 1
# VM 430 released from Host 0
# VM 451 allocated to Host 0
# VM 441 allocated to Host 1
# VM 441 released from Host 0
# VM 441 released from Host 1
# VM 461 allocated to Host 0
# VM 451 allocated to Host 1
# VM 451 released from Host 0
# VM 451 released from Host 1
# VM 470 allocated to Host 0
# VM 470 allocated to Host 1
# VM 470 released from Host 0
# VM 470 released from Host 1
# VM 461 allocated to Host 1
# VM 461 released from Host 0
# VM 461 released from Host 1
# VM 480 allocated to Host 0
# VM 488 allocated to Host 0
# VM 480 allocated to Host 1
# VM 480 released from Host 0
# VM 480 released from Host 1
# VM 494 allocated to Host 0
# VM 488 allocated to Host 1
# VM 488 released from Host 0
# VM 488 released from Host 1
# VM 502 allocated to Host 0
# VM 494 allocated to Host 1
# VM 494 released from Host 0
# VM 494 released from Host 1
# VM 502 allocated to Host 1
# VM 502 released from Host 0
# VM 502 released from Host 1
# VM 511 allocated to Host 0
# VM 516 allocated to Host 0
# VM 511 allocated to Host 1
# VM 511 released from Host 0
# VM 511 released from Host 1
# VM 525 allocated to Host 0
# VM 516 allocated to Host 1
# VM 516 released from Host 0
# VM 516 released from Host 1
# VM 535 allocated to Host 0
# VM 525 allocated to Host 1
# VM 525 released from Host 0
# VM 525 released from Host 1
# VM 541 allocated to Host 0
# VM 535 allocated to Host 1
# VM 535 released from Host 0
# VM 535 released from Host 1
# VM 551 allocated to Host 0
# VM 554 allocated to Host 0
# VM 541 released from Host 0
# VM 562 allocated to Host 0
# VM 551 allocated to Host 1
# VM 551 released from Host 0
# VM 551 released from Host 1
# VM 562 allocated to Host 1
# VM 562 released from Host 0
# VM 562 released from Host 1
# VM 554 allocated to Host 1
# VM 554 released from Host 0
# VM 554 released from Host 1
# VM 572 allocated to Host 0
# VM 581 allocated to Host 0
# VM 572 allocated to Host 1
# VM 572 released from Host 0
# VM 572 released from Host 1
# VM 581 allocated to Host 1
# VM 581 released from Host 0
# VM 581 released from Host 1
# VM 591 allocated to Host 0
# VM 595 allocated to Host 0
# VM 591 allocated to Host 1
# VM 591 released from Host 0
# VM 591 released from Host 1
# VM 600 allocated to Host 0
# VM 604 allocated to Host 1
# VM 595 allocated to Host 1
# VM 595 released from Host 0
# VM 595 released from Host 1
# VM 612 allocated to Host 0
# VM 600 allocated to Host 1
# VM 600 released from Host 0
# VM 600 released from Host 1
# VM 612 allocated to Host 1
# VM 612 released from Host 0
# VM 612 released from Host 1
# VM 604 allocated to Host 0
# VM 604 released from Host 1
# VM 604 released from Host 0
# VM 622 allocated to Host 0
# VM 629 allocated to Host 0
# VM 635 allocated to Host 0
# VM 622 allocated to Host 1
# VM 622 released from Host 0
# VM 622 released from Host 1
# VM 629 allocated to Host 1
# VM 629 released from Host 0
# VM 629 released from Host 1
# VM 643 allocated to Host 0
# VM 647 allocated to Host 1
# VM 648 allocated to Host 1
# VM 635 allocated to Host 2
# VM 635 released from Host 0
# VM 635 released from Host 2
# VM 651 allocated to Host 0
# VM 648 allocated to Host 2
# VM 648 released from Host 1
# VM 648 released from Host 2
# VM 643 allocated to Host 1
# VM 643 released from Host 0
# VM 643 released from Host 1
# VM 651 allocated to Host 1
# VM 651 released from Host 0
# VM 651 released from Host 1
# VM 647 allocated to Host 0
# VM 647 released from Host 1
# VM 647 released from Host 0
# VM 660 allocated to Host 0
# VM 663 allocated to Host 0
# VM 660 allocated to Host 1
# VM 660 released from Host 0
# VM 660 released from Host 1
# VM 673 allocated to Host 0
# VM 663 allocated to Host 1
# VM 663 released from Host 0
# VM 663 released from Host 1
# VM 676 allocated to Host 0
# VM 683 allocated to Host 1
# VM 673 allocated to Host 1
# VM 673 released from Host 0
# VM 673 released from Host 1
# VM 690 allocated to Host 0
# VM 683 allocated to Host 0
# VM 683 released from Host 1
# VM 683 released from Host 0
# VM 676 allocated to Host 1
# VM 676 released from Host 0
# VM 676 released from Host 1
# VM 696 allocated to Host 0
# VM 690 allocated to Host 1
# VM 690 released from Host 0
# VM 690 released from Host 1
# VM 700 allocated to Host 0
# VM 702 allocated to Host 1
# VM 696 allocated to Host 1
# VM 696 released from Host 0
# VM 696 released from Host 1
# VM 704 allocated to Host 0
# VM 706 allocated to Host 0
# VM 709 allocated to Host 1
# VM 704 allocated to Host 1
# VM 704 released from Host 0
# VM 704 released from Host 1
# VM 700 allocated to Host 2
# VM 700 released from Host 0
# VM 700 released from Host 2
# VM 702 allocated to Host 0
# VM 702 released from Host 1
# VM 702 released from Host 0
# VM 718 allocated to Host 0
# VM 709 allocated to Host 2
# VM 709 released from Host 1
# VM 709 released from Host 2
# VM 706 allocated to Host 1
# VM 706 released from Host 0
# VM 706 released from Host 1
# VM 724 allocated to Host 0
# VM 718 allocated to Host 1
# VM 718 released from Host 0
# VM 718 released from Host 1
# VM 733 allocated to Host 0
# VM 724 allocated to Host 1
# VM 724 released from Host 0
# VM 724 released from Host 1
# VM 733 allocated to Host 1
# VM 733 released from Host 0
# VM 733 released from Host 1
# VM 740 allocated to Host 0
# VM 740 released from Host 0
# VM 750 allocated to Host 0
# VM 751 allocated to Host 0
# VM 751 allocated to Host 1
# VM 751 released from Host 0
# VM 751 released from Host 1
# VM 758 allocated to Host 0
# VM 760 allocated to Host 0
# VM 750 allocated to Host 1
# VM 750 released from Host 0
# VM 750 released from Host 1
# VM 758 allocated to Host 1
# VM 758 released from Host 0
# VM 758 released from Host 1
# VM 760 allocated to Host 1
# VM 760 released from Host 0
# VM 760 released from Host 1
# VM 768 allocated to Host 0
# VM 773 allocated to Host 0
# VM 777 allocated to Host 1
# VM 768 allocated to Host 1
# VM 768 released from Host 0
# VM 768 released from Host 1
# VM 777 allocated to Host 0
# VM 777 released from Host 1
# VM 777 released from Host 0
# VM 787 allocated to Host 0
# VM 773 allocated to Host 1
# VM 773 released from Host 0
# VM 773 released from Host 1
# VM 789 allocated to Host 0
# VM 793 allocated to Host 1
# VM 787 released from Host 0
# VM 789 released from Host 0
# VM 801 allocated to Host 0
# VM 804 allocated to Host 0
# VM 805 allocated to Host 1
# VM 793 released from Host 1
# VM 801 allocated to Host 1
# VM 801 released from Host 0
# VM 801 released from Host 1
# VM 805 allocated to Host 0
# VM 805 released from Host 1
# VM 805 released from Host 0
# VM 804 allocated to Host 1
# VM 804 released from Host 0
# VM 804 released from Host 1
# VM 813 allocated to Host 0
# VM 823 allocated to Host 0
# VM 826 allocated to Host 0
# VM 813 allocated to Host 1
# VM 813 released from Host 0
# VM 813 released from Host 1
# VM 823 allocated to Host 1
# VM 823 released from Host 0
# VM 823 released from Host 1
# VM 836 allocated to Host 0
# VM 826 allocated to Host 1
# VM 826 released from Host 0
# VM 826 released from Host 1
# VM 841 allocated to Host 0
# VM 836 allocated to Host 1
# VM 836 released from Host 0
# VM 836 released from Host 1
# VM 843 allocated to Host 0
# VM 846 allocated to Host 0
# VM 841 allocated to Host 1
# VM 841 released from Host 0
# VM 841 released from Host 1
# VM 854 allocated to Host 1
# VM 843 allocated to Host 1
# VM 843 released from Host 0
# VM 843 released from Host 1
# VM 846 allocated to Host 1
# VM 846 released from Host 0
# VM 846 released from Host 1
# VM 858 allocated to Host 0
# VM 858 allocated to Host 1
# VM 858 released from Host 0
# VM 858 released from Host 1
# VM 867 allocated to Host 0
# VM 854 allocated to Host 0
# VM 854 released from Host 1
# VM 854 released from Host 0
# VM 871 allocated to Host 0
# VM 867 allocated to Host 1
# VM 867 released from Host 0
# VM 867 released from Host 1
# VM 878 allocated to Host 0
# VM 881 allocated to Host 1
# VM 871 allocated to Host 1
# VM 871 released from Host 0
# VM 871 released from Host 1
# VM 884 allocated to Host 0
# VM 878 allocated to Host 1
# VM 878 released from Host 0
# VM 878 released from Host 1
# VM 889 allocated to Host 0
# VM 881 allocated to Host 2
# VM 881 released from Host 1
# VM 881 released from Host 2
# VM 884 allocated to Host 1
# VM 884 released from Host 0
# VM 884 released from Host 1
# VM 897 allocated to Host 0
# VM 889 allocated to Host 1
# VM 889 released from Host 0
# VM 889 released from Host 1
# VM 906 allocated to Host 0
# VM 897 allocated to Host 1
# VM 897 released from Host 0
# VM 897 released from Host 1
# VM 906 allocated to Host 1
# VM 906 released from Host 0
# VM 906 released from Host 1
# VM 915 allocated to Host 0
# VM 921 allocated to Host 0
# VM 915 allocated to Host 1
# VM 915 released from Host 0
# VM 915 released from Host 1
# VM 930 allocated to Host 0
# VM 931 allocated to Host 0
# VM 933 allocated to Host 1
# VM 921 released from Host 0
# VM 941 allocated to Host 1
# VM 930 allocated to Host 1
# VM 930 released from Host 0
# VM 930 released from Host 1
# VM 933 allocated to Host 0
# VM 933 released from Host 1
# VM 933 released from Host 0
# VM 931 allocated to Host 1
# VM 931 released from Host 0
# VM 931 released from Host 1
# VM 941 allocated to Host 0
# VM 941 released from Host 1
# VM 941 released from Host 0
# VM 949 allocated to Host 0
# VM 955 allocated to Host 0
# VM 963 allocated to Host 0
# VM 949 allocated to Host 1
# VM 949 released from Host 0
# VM 949 released from Host 1
# VM 955 allocated to Host 1
# VM 955 released from Host 0
# VM 955 released from Host 1
# VM 973 allocated to Host 0
# VM 963 allocated to Host 1
# VM 963 released from Host 0
# VM 963 released from Host 1
# VM 975 allocated to Host 0
# VM 978 allocated to Host 1
# VM 980 allocated to Host 1
# VM 973 allocated to Host 2
# VM 973 released from Host 0
# VM 973 released from Host 2
# VM 980 allocated to Host 0
# VM 980 released from Host 1
# VM 980 released from Host 0
# VM 989 allocated to Host 0
# VM 975 allocated to Host 1
# VM 975 released from Host 0
# VM 975 released from Host 1
# VM 978 allocated to Host 0
# VM 978 released from Host 1
# VM 978 released from Host 0
# VM 989 allocated to Host 1
# VM 989 released from Host 0
# VM 989 released from Host 1
# VM 999 allocated to Host 0
# Simulation finished.
# Host 0 utilization: 0.41
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00
# Average Host Utilization: 0.08
# Number of Migrations: 168
# Efficiency: -0.09
# Accuracy: 0.31

# %%
pip install google-cloud-monitoring
# Out:
# Collecting google-cloud-monitoring
#   Downloading google_cloud_monitoring-2.21.0-py2.py3-none-any.whl (344 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.9/344.9 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-monitoring) (2.11.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-monitoring) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-monitoring) (1.23.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-monitoring) (3.20.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-monitoring) (1.63.1)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-monitoring) (2.31.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-monitoring) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-monitoring) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-monitoring) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-monitoring) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-monitoring) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-monitoring) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-monitoring) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-monitoring) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-monitoring) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-monitoring) (2024.6.2)
# Installing collected packages: google-cloud-monitoring
# Successfully installed google-cloud-monitoring-2.21.0

# %%
# !pip install simpy
# Out:
# Requirement already satisfied: simpy in /usr/local/lib/python3.10/dist-packages (4.1.1)

# %%
# !pip install google-cloud-monitoring simpy
# Out:
# Requirement already satisfied: google-cloud-monitoring in /usr/local/lib/python3.10/dist-packages (2.21.0)
# Requirement already satisfied: simpy in /usr/local/lib/python3.10/dist-packages (4.1.1)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-monitoring) (2.11.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-monitoring) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-monitoring) (1.23.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-monitoring) (3.20.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-monitoring) (1.63.1)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-monitoring) (2.31.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-monitoring) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-monitoring) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-monitoring) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-monitoring) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-monitoring) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-monitoring) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-monitoring) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-monitoring) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-monitoring) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-monitoring) (2024.6.2)

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/content/qwiklabs-gcp-03-103a595de79c-f295ae08711b.json"

# %%
import datetime
from google.cloud import monitoring_v3
import simpy
import random

# Google Cloud Monitoring client
client = monitoring_v3.MetricServiceClient()

# Function to fetch real-time metrics from Google Cloud Monitoring
def fetch_cloud_metrics(project_id, instance_id):
    now = datetime.datetime.now(datetime.timezone.utc)
    interval = monitoring_v3.TimeInterval(
        {
            "end_time": now,
            "start_time": now - datetime.timedelta(minutes=5),
        }
    )

    results = client.list_time_series(
        request={
            "name": f"projects/{project_id}",
            "filter": f'metric.type="compute.googleapis.com/instance/cpu/utilization" AND resource.labels.instance_id="{instance_id}"',
            "interval": interval,
            "view": monitoring_v3.ListTimeSeriesRequest.TimeSeriesView.FULL,
        }
    )

    datapoints = []
    for result in results:
        for point in result.points:
            datapoints.append({
                "timestamp": point.interval.end_time,
                "average": point.value.double_value
            })

    return datapoints

class Host:
    def __init__(self, id, cpu_capacity, memory_capacity):
        self.id = id
        self.cpu_capacity = cpu_capacity
        self.memory_capacity = memory_capacity
        self.available_cpu = cpu_capacity
        self.available_memory = memory_capacity
        self.vms = []

    def allocate_resources(self, vm):
        if self.available_cpu >= vm.cpu and self.available_memory >= vm.memory:
            self.available_cpu -= vm.cpu
            self.available_memory -= vm.memory
            self.vms.append(vm)
            return True
        return False

    def release_resources(self, vm):
        self.available_cpu += vm.cpu
        self.available_memory += vm.memory
        self.vms.remove(vm)

class VM:
    def __init__(self, id, cpu, memory, start_time, end_time):
        self.id = id
        self.cpu = cpu
        self.memory = memory
        self.start_time = start_time
        self.end_time = end_time
        self.host = None

class QLearningAgent:
    def __init__(self, alpha, gamma, epsilon):
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.q_table = {}

    def get_state(self, host, vm):
        return (host.id, vm.id)

    def choose_action(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(['migrate', 'stay'])
        else:
            return max(self.q_table.get(state, {'migrate': 0, 'stay': 0}), key=self.q_table.get(state, {'migrate': 0, 'stay': 0}).get)

    def update_q_value(self, state, action, reward, next_state):
        old_value = self.q_table.get(state, {}).get(action, 0)
        future_reward = max(self.q_table.get(next_state, {}).values(), default=0)
        new_value = old_value + self.alpha * (reward + self.gamma * future_reward - old_value)
        if state not in self.q_table:
            self.q_table[state] = {}
        self.q_table[state][action] = new_value

# %%
import datetime
from google.cloud import monitoring_v3
import simpy
import random

# Google Cloud Monitoring client
client = monitoring_v3.MetricServiceClient()

# Function to fetch real-time metrics from Google Cloud Monitoring
def fetch_cloud_metrics(project_id, instance_id):
    now = datetime.datetime.now(datetime.timezone.utc)
    interval = monitoring_v3.TimeInterval(
        {
            "end_time": now,
            "start_time": now - datetime.timedelta(minutes=5),
        }
    )

    results = client.list_time_series(
        request={
            "name": f"projects/{project_id}",
            "filter": f'metric.type="compute.googleapis.com/instance/cpu/utilization" AND resource.labels.instance_id="{instance_id}"',
            "interval": interval,
            "view": monitoring_v3.ListTimeSeriesRequest.TimeSeriesView.FULL,
        }
    )

    datapoints = []
    for result in results:
        for point in result.points:
            datapoints.append({
                "timestamp": point.interval.end_time,
                "average": point.value.double_value
            })

    return datapoints

class Host:
    def __init__(self, id, cpu_capacity, memory_capacity):
        self.id = id
        self.cpu_capacity = cpu_capacity
        self.memory_capacity = memory_capacity
        self.available_cpu = cpu_capacity
        self.available_memory = memory_capacity
        self.vms = []

    def allocate_resources(self, vm):
        if self.available_cpu >= vm.cpu and self.available_memory >= vm.memory:
            self.available_cpu -= vm.cpu
            self.available_memory -= vm.memory
            self.vms.append(vm)
            return True
        return False

    def release_resources(self, vm):
        self.available_cpu += vm.cpu
        self.available_memory += vm.memory
        self.vms.remove(vm)

class VM:
    def __init__(self, id, cpu, memory, start_time, end_time):
        self.id = id
        self.cpu = cpu
        self.memory = memory
        self.start_time = start_time
        self.end_time = end_time
        self.host = None

class QLearningAgent:
    def __init__(self, alpha, gamma, epsilon):
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.q_table = {}

    def get_state(self, host, vm):
        return (host.id, vm.id)

    def choose_action(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(['migrate', 'stay'])
        else:
            return max(self.q_table.get(state, {'migrate': 0, 'stay': 0}), key=self.q_table.get(state, {'migrate': 0, 'stay': 0}).get)

    def update_q_value(self, state, action, reward, next_state):
        old_value = self.q_table.get(state, {}).get(action, 0)
        future_reward = max(self.q_table.get(next_state, {}).values(), default=0)
        new_value = old_value + self.alpha * (reward + self.gamma * future_reward - old_value)
        if state not in self.q_table:
            self.q_table[state] = {}
        self.q_table[state][action] = new_value

# %%
def calculate_reward(host):
    utilization = (host.cpu_capacity - host.available_cpu) / host.cpu_capacity
    return utilization

def handle_vm_lifetime(env, vm, hosts, agent):
    for host in hosts:
        if host.allocate_resources(vm):
            vm.host = host
            break

    if vm.host is None:
        return

    lifetime = vm.end_time - vm.start_time
    yield env.timeout(lifetime)

    state = agent.get_state(vm.host, vm)
    action = agent.choose_action(state)

    if action == 'migrate':
        for host in hosts:
            if host != vm.host and host.allocate_resources(vm):
                vm.host.release_resources(vm)
                vm.host = host
                break

    reward = calculate_reward(vm.host)
    next_state = agent.get_state(vm.host, vm)
    agent.update_q_value(state, action, reward, next_state)

    vm.host.release_resources(vm)

# %%
def generate_vm_workload(env, project_id, instance_id, hosts, agent):
    while True:
        metrics = fetch_cloud_metrics(project_id, instance_id)
        for metric in metrics:
            start_time = metric['timestamp'].timestamp()
            end_time = start_time + 3  # Assuming 5-minute intervals
            cpu_demand = metric['average']
            memory_demand = random.uniform(0.1, 1.0) * 100

            vm_id = int(start_time)
            vm = VM(vm_id, cpu_demand, memory_demand, start_time, end_time)
            env.process(handle_vm_lifetime(env, vm, hosts, agent))
            yield env.timeout(6)  # Wait for the next interval to fetch new metrics

# %%
def print_host_utilization(hosts):
    for host in hosts:
        utilization = (host.cpu_capacity - host.available_cpu) / host.cpu_capacity
        print(f'Host {host.id} utilization: {utilization:.2f}')

# %%
# Simulation parameters
simulation_duration = 10  # Short duration for quick test
alpha = 0.1
gamma = 0.9
epsilon = 0.1

# Initialize environment and components
env = simpy.Environment()
hosts = [Host(i, 100, 100) for i in range(3)]  # Reduced number of hosts for simplicity
agent = QLearningAgent(alpha, gamma, epsilon)

# Example project ID and instance ID
project_id = 'qwiklabs-gcp-03-103a595de79c'
instance_id = 'instance-20240607-152435'

env.process(generate_vm_workload(env, project_id, instance_id, hosts, agent))
env.run(until=simulation_duration)

print_host_utilization(hosts)
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      71         try:
# ---> 72             return callable_(*args, **kwargs)
#      73         except grpc.RpcError as exc:
#
# /usr/local/lib/python3.10/dist-packages/grpc/_channel.py in __call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1180         )
# -> 1181         return _end_unary_response_blocking(state, call, False, None)
#    1182
#
# /usr/local/lib/python3.10/dist-packages/grpc/_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#    1005     else:
# -> 1006         raise _InactiveRpcError(state)  # pytype: disable=not-instantiable
#    1007
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.PERMISSION_DENIED
# 	details = "Project #1080153336926 has been deleted."
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:142.251.31.95:443 {grpc_message:"Project #1080153336926 has been deleted.", grpc_status:7, created_time:"2024-06-07T16:51:50.297036998+00:00"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# PermissionDenied                          Traceback (most recent call last)
# <ipython-input-8-b21bc403e637> in generate_vm_workload(env, project_id, instance_id, hosts, agent)
#       2     while True:
# ----> 3         metrics = fetch_cloud_metrics(project_id, instance_id)
#       4         for metric in metrics:
#
# <ipython-input-6-11daf8c8138f> in fetch_cloud_metrics(project_id, instance_id)
#      18
# ---> 19     results = client.list_time_series(
#      20         request={
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/monitoring_v3/services/metric_service/client.py in list_time_series(self, request, name, filter, interval, view, retry, timeout, metadata)
#    1583         # Send the request.
# -> 1584         response = rpc(
#    1585             request,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, *args, **kwargs)
#     112
# --> 113         return wrapped_func(*args, **kwargs)
#     114
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     348             )
# --> 349             return retry_target(
#     350                 target,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     190         try:
# --> 191             return target()
#     192
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     119
# --> 120             return func(*args, **kwargs)
#     121
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      73         except grpc.RpcError as exc:
# ---> 74             raise exceptions.from_grpc_error(exc) from exc
#      75
#
# PermissionDenied: 403 Project #1080153336926 has been deleted. [links {
#   description: "Google developer console API key"
#   url: "https://console.developers.google.com/project/1080153336926/apiui/credential"
# }
# , reason: "CONSUMER_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "consumer"
#   value: "projects/1080153336926"
# }
# metadata {
#   key: "service"
#   value: "monitoring.googleapis.com"
# }
# ]
#
# The above exception was the direct cause of the following exception:
#
# PermissionDenied                          Traceback (most recent call last)
# <ipython-input-10-953e361cb5d9> in <cell line: 17>()
#      15
#      16 env.process(generate_vm_workload(env, project_id, instance_id, hosts, agent))
# ---> 17 env.run(until=simulation_duration)
#      18
#      19 print_host_utilization(hosts)
#
# /usr/local/lib/python3.10/dist-packages/simpy/core.py in run(self, until)
#     244         try:
#     245             while True:
# --> 246                 self.step()
#     247         except StopSimulation as exc:
#     248             return exc.args[0]  # == until.value
#
# /usr/local/lib/python3.10/dist-packages/simpy/core.py in step(self)
#     202             exc = type(event._value)(*event._value.args)
#     203             exc.__cause__ = event._value
# --> 204             raise exc
#     205
#     206     def run(self, until: Optional[Union[SimTime, Event]] = None) -> Optional[Any]:
#
# PermissionDenied: 403 Project #1080153336926 has been deleted.

# %%
import datetime
from google.cloud import monitoring_v3
import simpy
import random
import os

# Set up Google Cloud credentials
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/content/qwiklabs-gcp-03-103a595de79c-f295ae08711b.json"

# Google Cloud Monitoring client
client = monitoring_v3.MetricServiceClient()

# Function to fetch real-time metrics from Google Cloud Monitoring
def fetch_cloud_metrics(project_id, instance_id):
    now = datetime.datetime.now(datetime.timezone.utc)
    interval = monitoring_v3.TimeInterval(
        {
            "end_time": now,
            "start_time": now - datetime.timedelta(minutes=5),
        }
    )

    results = client.list_time_series(
        request={
            "name": f"projects/{project_id}",
            "filter": f'metric.type="compute.googleapis.com/instance/cpu/utilization" AND resource.labels.instance_id="{instance_id}"',
            "interval": interval,
            "view": monitoring_v3.ListTimeSeriesRequest.TimeSeriesView.FULL,
        }
    )

    datapoints = []
    for result in results:
        for point in result.points:
            datapoints.append({
                "timestamp": point.interval.end_time,
                "average": point.value.double_value
            })

    return datapoints

class Host:
    def __init__(self, id, cpu_capacity, memory_capacity):
        self.id = id
        self.cpu_capacity = cpu_capacity
        self.memory_capacity = memory_capacity
        self.available_cpu = cpu_capacity
        self.available_memory = memory_capacity
        self.vms = []

    def allocate_resources(self, vm):
        if self.available_cpu >= vm.cpu and self.available_memory >= vm.memory:
            self.available_cpu -= vm.cpu
            self.available_memory -= vm.memory
            self.vms.append(vm)
            print(f"VM {vm.id} allocated to Host {self.id}")
            return True
        return False

    def release_resources(self, vm):
        self.available_cpu += vm.cpu
        self.available_memory += vm.memory
        self.vms.remove(vm)
        print(f"VM {vm.id} released from Host {self.id}")

class VM:
    def __init__(self, id, cpu, memory, start_time, end_time):
        self.id = id
        self.cpu = cpu
        self.memory = memory
        self.start_time = start_time
        self.end_time = end_time
        self.host = None

class QLearningAgent:
    def __init__(self, alpha, gamma, epsilon):
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.q_table = {}

    def get_state(self, host, vm):
        return (host.id, vm.id)

    def choose_action(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(['migrate', 'stay'])
        else:
            return max(self.q_table.get(state, {'migrate': 0, 'stay': 0}), key=self.q_table.get(state, {'migrate': 0, 'stay': 0}).get)

    def update_q_value(self, state, action, reward, next_state):
        old_value = self.q_table.get(state, {}).get(action, 0)
        future_reward = max(self.q_table.get(next_state, {}).values(), default=0)
        new_value = old_value + self.alpha * (reward + self.gamma * future_reward - old_value)
        if state not in self.q_table:
            self.q_table[state] = {}
        self.q_table[state][action] = new_value

def calculate_reward(host):
    utilization = (host.cpu_capacity - host.available_cpu) / host.cpu_capacity
    return utilization

def handle_vm_lifetime(env, vm, hosts, agent):
    for host in hosts:
        if host.allocate_resources(vm):
            vm.host = host
            break

    if vm.host is None:
        print(f"VM {vm.id} could not be allocated to any host")
        return

    lifetime = vm.end_time - vm.start_time
    yield env.timeout(lifetime)

    state = agent.get_state(vm.host, vm)
    action = agent.choose_action(state)

    if action == 'migrate':
        for host in hosts:
            if host != vm.host and host.allocate_resources(vm):
                vm.host.release_resources(vm)
                vm.host = host
                break

    reward = calculate_reward(vm.host)
    next_state = agent.get_state(vm.host, vm)
    agent.update_q_value(state, action, reward, next_state)

    vm.host.release_resources(vm)

def generate_vm_workload(env, project_id, instance_id, hosts, agent):
    while True:
        print("Fetching metrics...")
        metrics = fetch_cloud_metrics(project_id, instance_id)
        if not metrics:
            print("No metrics fetched, retrying in 5 seconds...")
            yield env.timeout(5)  # Retry after a short delay
            continue

        for metric in metrics:
            start_time = metric['timestamp'].timestamp()
            end_time = start_time + 3  # Assuming 5-minute intervals
            cpu_demand = metric['average']
            memory_demand = 50  # Fixed memory demand for simplicity

            vm_id = int(start_time)
            vm = VM(vm_id, cpu_demand, memory_demand, start_time, end_time)
            env.process(handle_vm_lifetime(env, vm, hosts, agent))
            yield env.timeout(6)  # Wait for the next interval to fetch new metrics

def print_host_utilization(hosts):
    for host in hosts:
        utilization = (host.cpu_capacity - host.available_cpu) / host.cpu_capacity
        print(f'Host {host.id} utilization: {utilization:.2f}')

# Simulation parameters
simulation_duration = 10  # Short duration for quick test
alpha = 0.1
gamma = 0.9
epsilon = 0.1

# Initialize environment and components
env = simpy.Environment()
hosts = [Host(i, 100, 100) for i in range(3)]  # Reduced number of hosts for simplicity
agent = QLearningAgent(alpha, gamma, epsilon)

# Example project ID and instance ID
project_id = 'qwiklabs-gcp-03-103a595de79c'
instance_id = 'instance-20240607-152435'

print("Starting simulation...")
env.process(generate_vm_workload(env, project_id, instance_id, hosts, agent))
env.run(until=simulation_duration)
print("Simulation finished.")

print_host_utilization(hosts)
# Out:
# Starting simulation...
# Fetching metrics...
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      71         try:
# ---> 72             return callable_(*args, **kwargs)
#      73         except grpc.RpcError as exc:
#
# /usr/local/lib/python3.10/dist-packages/grpc/_channel.py in __call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1180         )
# -> 1181         return _end_unary_response_blocking(state, call, False, None)
#    1182
#
# /usr/local/lib/python3.10/dist-packages/grpc/_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#    1005     else:
# -> 1006         raise _InactiveRpcError(state)  # pytype: disable=not-instantiable
#    1007
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.PERMISSION_DENIED
# 	details = "Project #1080153336926 has been deleted."
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:172.217.218.95:443 {created_time:"2024-06-07T16:55:02.061024979+00:00", grpc_status:7, grpc_message:"Project #1080153336926 has been deleted."}"
# >
#
# The above exception was the direct cause of the following exception:
#
# PermissionDenied                          Traceback (most recent call last)
# <ipython-input-11-95ac6d63b257> in generate_vm_workload(env, project_id, instance_id, hosts, agent)
#     134         print("Fetching metrics...")
# --> 135         metrics = fetch_cloud_metrics(project_id, instance_id)
#     136         if not metrics:
#
# <ipython-input-11-95ac6d63b257> in fetch_cloud_metrics(project_id, instance_id)
#      22
# ---> 23     results = client.list_time_series(
#      24         request={
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/monitoring_v3/services/metric_service/client.py in list_time_series(self, request, name, filter, interval, view, retry, timeout, metadata)
#    1583         # Send the request.
# -> 1584         response = rpc(
#    1585             request,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, *args, **kwargs)
#     112
# --> 113         return wrapped_func(*args, **kwargs)
#     114
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     348             )
# --> 349             return retry_target(
#     350                 target,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     190         try:
# --> 191             return target()
#     192
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     119
# --> 120             return func(*args, **kwargs)
#     121
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      73         except grpc.RpcError as exc:
# ---> 74             raise exceptions.from_grpc_error(exc) from exc
#      75
#
# PermissionDenied: 403 Project #1080153336926 has been deleted. [links {
#   description: "Google developer console API key"
#   url: "https://console.developers.google.com/project/1080153336926/apiui/credential"
# }
# , reason: "CONSUMER_INVALID"
# domain: "googleapis.com"
# metadata {
#   key: "consumer"
#   value: "projects/1080153336926"
# }
# metadata {
#   key: "service"
#   value: "monitoring.googleapis.com"
# }
# ]
#
# The above exception was the direct cause of the following exception:
#
# PermissionDenied                          Traceback (most recent call last)
# <ipython-input-11-95ac6d63b257> in <cell line: 174>()
#     172 print("Starting simulation...")
#     173 env.process(generate_vm_workload(env, project_id, instance_id, hosts, agent))
# --> 174 env.run(until=simulation_duration)
#     175 print("Simulation finished.")
#     176
#
# /usr/local/lib/python3.10/dist-packages/simpy/core.py in run(self, until)
#     244         try:
#     245             while True:
# --> 246                 self.step()
#     247         except StopSimulation as exc:
#     248             return exc.args[0]  # == until.value
#
# /usr/local/lib/python3.10/dist-packages/simpy/core.py in step(self)
#     202             exc = type(event._value)(*event._value.args)
#     203             exc.__cause__ = event._value
# --> 204             raise exc
#     205
#     206     def run(self, until: Optional[Union[SimTime, Event]] = None) -> Optional[Any]:
#
# PermissionDenied: 403 Project #1080153336926 has been deleted.

# %%
import datetime
import random
import os
import simpy
from azure.identity import DefaultAzureCredential
from azure.monitor.query import MetricsQueryClient, MetricAggregationType

# Set up Azure credentials
credential = DefaultAzureCredential()
client = MetricsQueryClient(credential)

# Function to fetch real-time metrics from Azure Monitor
def fetch_cloud_metrics(subscription_id, resource_group, vm_name):
    try:
        # Define the resource ID
        resource_id = (
            f"/subscriptions/{subscription_id}/resourceGroups/{resource_group}/providers/Microsoft.Compute/virtualMachines/{vm_name}"
        )

        # Query metrics
        response = client.query(
            resource_id,
            metric_names=["Percentage CPU"],
            timespan=datetime.timedelta(minutes=5),
            interval="PT1M",
            aggregations=[MetricAggregationType.AVERAGE]
        )

        datapoints = []
        for result in response.metrics[0].timeseries[0].data:
            if result.average is not None:
                datapoints.append({
                    "timestamp": result.timestamp,
                    "average": result.average
                })

        return datapoints
    except Exception as e:
        print(f"Error fetching metrics: {e}")
        return []

class Host:
    def __init__(self, id, cpu_capacity, memory_capacity):
        self.id = id
        self.cpu_capacity = cpu_capacity
        self.memory_capacity = memory_capacity
        self.available_cpu = cpu_capacity
        self.available_memory = memory_capacity
        self.vms = []

    def allocate_resources(self, vm):
        if self.available_cpu >= vm.cpu and self.available_memory >= vm.memory:
            self.available_cpu -= vm.cpu
            self.available_memory -= vm.memory
            self.vms.append(vm)
            print(f"VM {vm.id} allocated to Host {self.id}")
            return True
        return False

    def release_resources(self, vm):
        self.available_cpu += vm.cpu
        self.available_memory += vm.memory
        self.vms.remove(vm)
        print(f"VM {vm.id} released from Host {self.id}")

class VM:
    def __init__(self, id, cpu, memory, start_time, end_time):
        self.id = id
        self.cpu = cpu
        self.memory = memory
        self.start_time = start_time
        self.end_time = end_time
        self.host = None

class QLearningAgent:
    def __init__(self, alpha, gamma, epsilon):
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.q_table = {}

    def get_state(self, host, vm):
        return (host.id, vm.id)

    def choose_action(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(['migrate', 'stay'])
        else:
            return max(self.q_table.get(state, {'migrate': 0, 'stay': 0}), key=self.q_table.get(state, {'migrate': 0, 'stay': 0}).get)

    def update_q_value(self, state, action, reward, next_state):
        old_value = self.q_table.get(state, {}).get(action, 0)
        future_reward = max(self.q_table.get(next_state, {}).values(), default=0)
        new_value = old_value + self.alpha * (reward + self.gamma * future_reward - old_value)
        if state not in self.q_table:
            self.q_table[state] = {}
        self.q_table[state][action] = new_value

def calculate_reward(host):
    utilization = (host.cpu_capacity - host.available_cpu) / host.cpu_capacity
    return utilization

def handle_vm_lifetime(env, vm, hosts, agent):
    for host in hosts:
        if host.allocate_resources(vm):
            vm.host = host
            break

    if vm.host is None:
        print(f"VM {vm.id} could not be allocated to any host")
        return

    lifetime = vm.end_time - vm.start_time
    yield env.timeout(lifetime)

    state = agent.get_state(vm.host, vm)
    action = agent.choose_action(state)

    if action == 'migrate':
        for host in hosts:
            if host != vm.host and host.allocate_resources(vm):
                vm.host.release_resources(vm)
                vm.host = host
                break

    reward = calculate_reward(vm.host)
    next_state = agent.get_state(vm.host, vm)
    agent.update_q_value(state, action, reward, next_state)

    vm.host.release_resources(vm)

def generate_vm_workload(env, subscription_id, resource_group, vm_name, hosts, agent):
    while True:
        print("Fetching metrics...")
        metrics = fetch_cloud_metrics(subscription_id, resource_group, vm_name)
        if not metrics:
            print("No metrics fetched, using random data...")
            metrics = [{
                "timestamp": datetime.datetime.now(datetime.timezone.utc),
                "average": random.uniform(0.1, 0.9)
            }]

        for metric in metrics:
            start_time = metric['timestamp'].timestamp()
            end_time = start_time + 15  # Reduced interval for more real-time simulation
            cpu_demand = metric['average']
            memory_demand = 50  # Fixed memory demand for simplicity

            vm_id = int(start_time)
            vm = VM(vm_id, cpu_demand, memory_demand, start_time, end_time)
            env.process(handle_vm_lifetime(env, vm, hosts, agent))
            yield env.timeout(10)  # Wait for the next interval to fetch new metrics

def print_host_utilization(hosts):
    for host in hosts:
        utilization = (host.cpu_capacity - host.available_cpu) / host.cpu_capacity
        print(f'Host {host.id} utilization: {utilization:.2f}')

# Simulation parameters
simulation_duration = 1000  # Short duration for quick test
alpha = 0.1
gamma = 0.9
epsilon = 0.1

# Initialize environment and components
env = simpy.Environment()
hosts = [Host(i, 100, 100) for i in range(5)]  # Reduced number of hosts for simplicity
agent = QLearningAgent(alpha, gamma, epsilon)

# Example subscription ID, resource group, and VM name
subscription_id = 'd89493f7-fd93-418b-a882-dd9d2cb7c099'
resource_group = 'cat2_group'
vm_name = 'Hhi2003'

print("Starting simulation...")
env.process(generate_vm_workload(env, subscription_id, resource_group, vm_name, hosts, agent))
env.run(until=simulation_duration)
print("Simulation finished.")

print_host_utilization(hosts)
# Out:
# Starting simulation...
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 released from Host 0
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781748 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781748 allocated to Host 1
# VM 1717781748 released from Host 0
# VM 1717781748 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 released from Host 0
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 released from Host 0
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 released from Host 0
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 released from Host 0
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Fetching metrics...
# Error fetching metrics: 'MetricsQueryClient' object has no attribute 'query'
# No metrics fetched, using random data...
# VM 1717781749 allocated to Host 0
# VM 1717781749 allocated to Host 1
# VM 1717781749 released from Host 0
# VM 1717781749 released from Host 1
# Simulation finished.
# Host 0 utilization: 0.00
# Host 1 utilization: 0.00
# Host 2 utilization: 0.00
# Host 3 utilization: 0.00
# Host 4 utilization: 0.00

# %%
import datetime
import random
import os
import simpy
from azure.identity import DefaultAzureCredential
from azure.monitor.query import MetricsQueryClient, MetricAggregationType

# Set up Azure credentials
credential = DefaultAzureCredential()
client = MetricsQueryClient(credential)

# Function to fetch real-time metrics from Azure Monitor
def fetch_cloud_metrics(subscription_id, resource_group, vm_name):
    try:
        # Define the resource ID
        resource_id = (
            f"/subscriptions/{subscription_id}/resourceGroups/{resource_group}/providers/Microsoft.Compute/virtualMachines/{vm_name}"
        )

        print(f"Fetching metrics for resource ID: {resource_id}")

        # Query metrics
        response = client.query(
            resource_id,
            metric_names=["Percentage CPU"],
            timespan=datetime.timedelta(minutes=5),
            interval="PT1M",
            aggregations=[MetricAggregationType.AVERAGE]
        )

        datapoints = []
        if response.metrics:
            for result in response.metrics[0].timeseries[0].data:
                if result.average is not None:
                    datapoints.append({
                        "timestamp": result.timestamp,
                        "average": result.average
                    })
        else:
            print("No metrics available for the specified resource.")

        return datapoints
    except Exception as e:
        print(f"Error fetching metrics: {e}")
        return []

class Host:
    def __init__(self, id, cpu_capacity, memory_capacity):
        self.id = id
        self.cpu_capacity = cpu_capacity
        self.memory_capacity = memory_capacity
        self.available_cpu = cpu_capacity
        self.available_memory = memory_capacity
        self.vms = []

    def allocate_resources(self, vm):
        if self.available_cpu >= vm.cpu and self.available_memory >= vm.memory:
            self.available_cpu -= vm.cpu
            self.available_memory -= vm.memory
            self.vms.append(vm)
            print(f"VM {vm.id} allocated to Host {self.id}")
            return True
        return False

    def release_resources(self, vm):
        self.available_cpu += vm.cpu
        self.available_memory += vm.memory
        self.vms.remove(vm)
        print(f"VM {vm.id} released from Host {self.id}")

class VM:
    def __init__(self, id, cpu, memory, start_time, end_time):
        self.id = id
        self.cpu = cpu
        self.memory = memory
        self.start_time = start_time
        self.end_time = end_time
        self.host = None

class QLearningAgent:
    def __init__(self, alpha, gamma, epsilon):
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon = epsilon
        self.q_table = {}

    def get_state(self, host, vm):
        return (host.id, vm.id)

    def choose_action(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(['migrate', 'stay'])
        else:
            return max(self.q_table.get(state, {'migrate': 0, 'stay': 0}), key=self.q_table.get(state, {'migrate': 0, 'stay': 0}).get)

    def update_q_value(self, state, action, reward, next_state):
        old_value = self.q_table.get(state, {}).get(action, 0)
        future_reward = max(self.q_table.get(next_state, {}).values(), default=0)
        new_value = old_value + self.alpha * (reward + self.gamma * future_reward - old_value)
        if state not in self.q_table:
            self.q_table[state] = {}
        self.q_table[state][action] = new_value

def calculate_reward(host):
    utilization = (host.cpu_capacity - host.available_cpu) / host.cpu_capacity
    return utilization

def handle_vm_lifetime(env, vm, hosts, agent):
    for host in hosts:
        if host.allocate_resources(vm):
            vm.host = host
            break

    if vm.host is None:
        print(f"VM {vm.id} could not be allocated to any host")
        return

    lifetime = vm.end_time - vm.start_time
    yield env.timeout(lifetime)

    state = agent.get_state(vm.host, vm)
    action = agent.choose_action(state)

    if action == 'migrate':
        for host in hosts:
            if host != vm.host and host.allocate_resources(vm):
                vm.host.release_resources(vm)
                vm.host = host
                break

    reward = calculate_reward(vm.host)
    next_state = agent.get_state(vm.host, vm)
    agent.update_q_value(state, action, reward, next_state)

    vm.host.release_resources(vm)

def generate_vm_workload(env, subscription_id, resource_group, vm_name, hosts, agent):
    while True:
        print("Fetching metrics...")
        metrics = fetch_cloud_metrics(subscription_id, resource_group, vm_name)
        if not metrics:
            print("No metrics fetched.")
        else:
            for metric in metrics:
                start_time = metric['timestamp'].timestamp()
                end_time = start_time + 15  # Reduced interval for more real-time simulation
                cpu_demand = metric['average']
                memory_demand = 50  # Fixed memory demand for simplicity

                vm_id = int(start_time)
                vm = VM(vm_id, cpu_demand, memory_demand, start_time, end_time)
                env.process(handle_vm_lifetime(env, vm, hosts, agent))
                yield env.timeout(10)  # Wait for the next interval to fetch new metrics

def print_host_utilization(hosts):
    for host in hosts:
        utilization = (host.cpu_capacity - host.available_cpu) / host.cpu_capacity
        print(f'Host {host.id} utilization: {utilization:.2f}')

# Simulation parameters
simulation_duration = 1000  # Short duration for quick test
alpha = 0.1
gamma = 0.9
epsilon = 0.1

# Initialize environment and components
env = simpy.Environment()
hosts = [Host(i, 100, 100) for i in range(5)]  # Reduced number of hosts for simplicity
agent = QLearningAgent(alpha, gamma, epsilon)

# Example subscription ID, resource group, and VM name
subscription_id = 'd89493f7-fd93-418b-a882-dd9d2cb7c099'
resource_group = 'cat2_group'
vm_name = 'Hhi2003'

print("Starting simulation...")
env.process(generate_vm_workload(env, subscription_id, resource_group, vm_name, hosts, agent))
env.run(until=simulation_duration)
print("Simulation finished.")

print_host_utilization(hosts)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-c0ecfafb97eb> in <cell line: 4>()
#       2 import random
#       3 import os
# ----> 4 import simpy
#       5 from azure.identity import DefaultAzureCredential
#       6 from azure.monitor.query import MetricsQueryClient, MetricAggregationType
#
# ModuleNotFoundError: No module named 'simpy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install azure-monitor-query
# !pip install azure-identity
# Out:
# Requirement already satisfied: azure-monitor-query in /usr/local/lib/python3.10/dist-packages (1.3.0)
# Requirement already satisfied: azure-core>=1.28.0 in /usr/local/lib/python3.10/dist-packages (from azure-monitor-query) (1.30.2)
# Requirement already satisfied: isodate>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from azure-monitor-query) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from azure-monitor-query) (4.12.1)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.28.0->azure-monitor-query) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.28.0->azure-monitor-query) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-monitor-query) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-monitor-query) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-monitor-query) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.28.0->azure-monitor-query) (2024.6.2)
# Requirement already satisfied: azure-identity in /usr/local/lib/python3.10/dist-packages (1.16.0)
# Requirement already satisfied: azure-core>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from azure-identity) (1.30.2)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.10/dist-packages (from azure-identity) (42.0.7)
# Requirement already satisfied: msal>=1.24.0 in /usr/local/lib/python3.10/dist-packages (from azure-identity) (1.28.0)
# Requirement already satisfied: msal-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from azure-identity) (1.1.0)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.23.0->azure-identity) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.23.0->azure-identity) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.23.0->azure-identity) (4.12.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.5->azure-identity) (1.16.0)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in /usr/lib/python3/dist-packages (from msal>=1.24.0->azure-identity) (2.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from msal-extensions>=0.3.0->azure-identity) (24.0)
# Requirement already satisfied: portalocker<3,>=1.0 in /usr/local/lib/python3.10/dist-packages (from msal-extensions>=0.3.0->azure-identity) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-identity) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-identity) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-identity) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-identity) (2024.6.2)

# %%
from azure.monitor.query import MetricsQueryClient

# %%
# !pip install azure-identity azure-monitor-query
# Out:
# Collecting azure-identity
#   Downloading azure_identity-1.16.0-py3-none-any.whl (166 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.1/166.1 kB 3.6 MB/s eta 0:00:00
# Collecting azure-monitor-query
#   Downloading azure_monitor_query-1.3.0-py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.3/162.3 kB 6.2 MB/s eta 0:00:00
# Collecting azure-core>=1.23.0 (from azure-identity)
#   Downloading azure_core-1.30.2-py3-none-any.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.3/194.3 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.10/dist-packages (from azure-identity) (42.0.7)
# Collecting msal>=1.24.0 (from azure-identity)
#   Downloading msal-1.28.0-py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 5.9 MB/s eta 0:00:00
# Collecting msal-extensions>=0.3.0 (from azure-identity)
#   Downloading msal_extensions-1.1.0-py3-none-any.whl (19 kB)
# Collecting isodate>=0.6.0 (from azure-monitor-query)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from azure-monitor-query) (4.12.1)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.23.0->azure-identity) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.23.0->azure-identity) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.5->azure-identity) (1.16.0)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in /usr/lib/python3/dist-packages (from msal>=1.24.0->azure-identity) (2.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from msal-extensions>=0.3.0->azure-identity) (24.0)
# Collecting portalocker<3,>=1.0 (from msal-extensions>=0.3.0->azure-identity)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-identity) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-identity) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-identity) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core>=1.23.0->azure-identity) (2024.6.2)
# Installing collected packages: portalocker, isodate, azure-core, azure-monitor-query, msal, msal-extensions, azure-identity
# Successfully installed azure-core-1.30.2 azure-identity-1.16.0 azure-monitor-query-1.3.0 isodate-0.6.1 msal-1.28.0 msal-extensions-1.1.0 portalocker-2.8.2

# %%
# !pip install chatterbot
# Out:
# Collecting chatterbot
#   Downloading ChatterBot-1.0.5-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting mathparse<0.2,>=0.1 (from chatterbot)
#   Downloading mathparse-0.1.2-py3-none-any.whl.metadata (776 bytes)
# Requirement already satisfied: nltk<4.0,>=3.2 in /usr/local/lib/python3.10/dist-packages (from chatterbot) (3.8.1)
# Collecting pint>=0.8.1 (from chatterbot)
#   Downloading Pint-0.24.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting pymongo<4.0,>=3.3 (from chatterbot)
#   Downloading pymongo-3.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Collecting python-dateutil<2.8,>=2.7 (from chatterbot)
#   Downloading python_dateutil-2.7.5-py2.py3-none-any.whl.metadata (7.5 kB)
# Collecting pyyaml<5.2,>=5.1 (from chatterbot)
#   Downloading PyYAML-5.1.2.tar.gz (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.0/265.0 kB 17.3 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import chatterbot.comparisons
import chatterbot.response_selection
from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer
from chatterbot.conversation import Statement
# from spellchecker import SpellChecker
import logging

# def get_feedback():

#     text = input()

#     if 'yes' in text.lower():
#         return True
#     elif 'no' in text.lower():
#         return False
#     else:
#         print('Please type either "Yes" or "No"')
#         return get_feedback()

class Chat_Bot():

    def __init__(self):
        self.chatbot1 = ChatBot('Bakery Help',storage_adapter="chatterbot.storage.SQLStorageAdapter" ,logic_adapters=[
        {
                    'import_path': 'chatterbot.logic.BestMatch',
                    'default_response': 'I am sorry, but I do not understand.',
                    "statement_comparison_function": chatterbot.comparisons.LevenshteinDistance,
                    # "response_selection_method": chatterbot.response_selection.get_first_response
                    # 'maximum_similarity_threshold': 0.90
                }
            ]
            )
        logger=logging.getLogger()
        logger.setLevel(logging.CRITICAL)

        with open('greetings.txt','r') as data:
            welcome = data.read().splitlines()

        with open('asking_a_menu.txt','r') as ask:
            ask_menu = ask.read().splitlines()

        with open('seasonal_menu.txt','r') as ask1:
            seasonal_menu = ask1.read().splitlines()

        with open('gift_box.txt','r') as ask2:
            gift_box = ask2.read().splitlines()

        with open('macarons.txt','r') as d1:
            macaron = d1.read().splitlines()

        with open('chouquette.txt','r') as d2:
            chouquette = d2.read().splitlines()

        with open('creme_brulee.txt','r') as d3:
            creme_brulee = d3.read().splitlines()

        with open('croissant.txt','r') as d4:
            croissant = d4.read().splitlines()

        with open('eclair.txt','r') as d5:
            eclair = d5.read().splitlines()

        with open('mille_feuille.txt','r') as d6:
            mille_feuille = d6.read().splitlines()

        with open('pain_au_chocolat.txt','r') as d7:
            pain_au_chocolat = d7.read().splitlines()

        with open('pralines.txt','r') as d8:
            pralines = d8.read().splitlines()

        with open('profiterole.txt','r') as d9:
            profiterole = d9.read().splitlines()

        with open('extra_questions.txt','r') as d10:
            extra_questions = d10.read().splitlines()


        # trainer = ListTrainer(self.chatbot1)
        # trainer.train(welcome)
        # trainer.train(ask_menu)
        # trainer.train(seasonal_menu)
        # trainer.train(gift_box)
        # trainer.train(macaron)
        # trainer.train(chouquette)
        # trainer.train(creme_brulee)
        # trainer.train(croissant)
        # trainer.train(eclair)
        # trainer.train(mille_feuille)
        # trainer.train(pain_au_chocolat)
        # trainer.train(pralines)
        # trainer.train(profiterole)
        # trainer.train(extra_questions)


        # spell = SpellChecker()

        # print("Lets chat! Enter bye to exit")
    def get_chatbot_response(self,message):
        while True:
            try:
                input_statement = Statement(text=message)
                if "bye" in str(input_statement):
                    return "exit"
                elif "thank you" in str(input_statement):
                    response= "Is there anything else I can help you with ? Enter bye to exit"
                else:
                    response = self.chatbot1.generate_response(input_statement)

                    # print("\U0001F9C1 ",response.text)
                # print('\n Is "{}" a coherent response to "{}"? \n'.format(
                #     response.text,
                #     input_statement.text
                # ))
                # if get_feedback() is False:
                #     print('please input the correct one')
                #     correct_response = Statement(text=input())
                #     chatbot1.learn_response(correct_response, input_statement)
                #     print('Responses added to bot!')
                return response
            except (KeyboardInterrupt, EOFError, SystemExit):
                break
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e4db5033bd76> in <cell line: 1>()
# ----> 1 import chatterbot.comparisons
#       2 import chatterbot.response_selection
#       3 from chatterbot import ChatBot
#       4 from chatterbot.trainers import ListTrainer
#       5 from chatterbot.conversation import Statement
#
# ModuleNotFoundError: No module named 'chatterbot'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
